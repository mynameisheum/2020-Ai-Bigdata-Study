# %% [markdown]
# - 내용 및 코드 참조
#
#   - 케라스 창시자로부터 배우는 딥러닝
#
#   - 미술관에 GAN 딥러닝 실전 프로젝트

# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 만다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# ### GAN 생성자 네트워크

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,LeakyReLU, Reshape, Conv2D, Conv2DTranspose, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

# %%
generator_input = Input(shape = (latent_dim, ))

# %%
x = Dense(128* 16*16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16,16,128))(x) # 128개의 채널로 만들어주고

x = Conv2D(256, 5, padding = 'same')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(256, 4 ,strides = 2, padding = 'same')(x)
x = LeakyReLU()(x)

x = Conv2D(256, 5, padding = 'same')(x)
x = LeakyReLU()(x)
x = Conv2D(256, 5, padding = 'same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7 ,activation = 'tanh', padding = 'same')(x)   # 한개의 채널을 가지도록

# %%
generator = Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32768)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GAN 판별자 네트워크

# %%
discriminator_input = Input(shape = (height, width, channels))

# %%
x = Conv2D(128,3)(discriminator_input)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides = 2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides = 2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides = 2)(x)
x = LeakyReLU()(x)
x = Flatten()(x)
x=Dropout(0.4)(x)   # dropout넣어주고
x = Dense(1, activation = 'sigmoid')(x)

# %%
discriminator = Model(discriminator_input,x)
discriminator.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
discriminator_optimizer = RMSprop(lr = 0.0008, clipvalue = 1.0, decay = 1e-8)   # 학습률감쇠 1ㄷ-8
discriminator.compile(optimizer = discriminator_optimizer ,
                      loss = 'binary_crossentropy')

# %% [markdown]
# ### 적대적 네트워크
# - 생성자와 판별자를 연결
#
# - 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습
#
# - 잠재 공간의 포인트를 진짜 또는 가짜의 분류 결정으로 변환
#
# - 훈련에 사용되는 target label은 항상 "진짜 이미지"
#
# - 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 매우 중요!
#
#   - 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 진짜를 예측하도록 훈련됨

# %%
discriminator.trainable = False

gan_input = Input(shape = (latent_dim, ))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)

gan_optimizer = RMSprop(lr=0.0004, clipvalue = 1.0, decay = 1e-8)
gan.compile(optimizer = gan_optimizer, 
            loss = 'binary_crossentropy')

# %% [markdown]
# ### GAN 훈련 구현
#
# - DCGAN 구현
#
# - 매 반복마다 아래의 과정 수행
#
#   1. 잠재 공간에서 무작위로 포인트를 뽑음(랜덤 노이즈)
#
#   2. 랜덤 노이즈를 사용하여 generator에서 이미지를 생성
#
#   3. 생성된 이미지와 진짜 이미지를 섞음
#
#   4. 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
#     타킷은 진짜 또는 가짜
#
#   5. 잠재 공간에서 무작위로 새로운 포인트를 뽑음
#
#   6. 랜덤 벡터를 사용하여 gan을 훈련.
#     모든 타깃은 진짜로 설정.
#     - 판별자가 생성된 이미지를 모두 "진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트.
#       (판별자는 동결되기 때문에 생성자만 업데이트)

# %%
import os   # 이미지파일을 다루기 위해서 불러오고
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #### CIFAR10 데이터 로드

# %%
(x_train, y_train), (_,_) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# #### 개구리 이미지를 선택

# %%
x_train = x_train[y_train.flatten() == 6]   # 6이 개구리 이미지니까 개루리만 가져오자

# %% [markdown]
# #### 데이터 정규화

# %%
x_train = x_train.reshape((x_train.shape[0], ) + (height, width , channels)).astype('float32') / 255.

# %%
iterations = 10000
batch_size = 20

save_dir = '/content/gan_images/'

if not os.path.exists(save_dir):    # 만약 디렉토리가 없으면 만들어줘!
    os.mkdir(save_dir)

# %% [markdown]
# #### 학습

# %%
start = 0
for step in range(iterations):
    random_latent_vectors = np.random.normal(size = (batch_size, latent_dim))
    generated_images = generator.predict(random_latent_vectors)

    # 진짜 이미지랑 congate해줘야지
    stop = start + batch_size
    real_images = x_train[start:stop]
    combined_images = np.concatenate([generated_images, real_images])   # 이미지 두개 합려주고

    labels = np.concatenate([np.ones((batch_size, 1)),              # 라벨도 합쳐주고
                             np.zeros((batch_size, 1))])
    labels += 0.05 * np.random.random(labels.shape)    # 노이즈를 추가해줘야지

    d_loss =discriminator.train_on_batch(combined_images, labels)

    random_latent_vectors = np.random.normal(size = (batch_size, latent_dim))
    misleading_targets = np.zeros((batch_size, 1))

    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

    start += batch_size
    if start > len(x_train) - batch_size:
        start = 0

    if step % 100 == 0:
        gan.save_weights('gan.h5')      # 100번마다 모델 저장해주고 이미지 보여줘야지

        print('\nstep: {}'.format(step))
        print(' discriminator loss: {}'.format(d_loss))
        print(' adversarial loss: {}'.format(a_loss))

        img = image.array_to_img(generated_images[0] * 255., scale = False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        img = image.array_to_img(real_images[0] * 255., scale = False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# step: 0
#  discriminator loss: 0.6838614344596863
#  adversarial loss: 0.6871287226676941
#
# step: 100
#  discriminator loss: 0.6629899144172668
#  adversarial loss: 0.9052572250366211
#
# step: 200
#  discriminator loss: 0.6971794366836548
#  adversarial loss: 0.9344391822814941
#
# step: 300
#  discriminator loss: 0.6915277242660522
#  adversarial loss: 0.7304852604866028
#
# step: 400
#  discriminator loss: 0.6918598413467407
#  adversarial loss: 0.7517719268798828
#
# step: 500
#  discriminator loss: 0.6890267133712769
#  adversarial loss: 0.7092949748039246
#
# step: 600
#  discriminator loss: 0.6885105967521667
#  adversarial loss: 0.7626145482063293
#
# step: 700
#  discriminator loss: 0.7003247141838074
#  adversarial loss: 0.736998438835144
#
# step: 800
#  discriminator loss: 0.6917085647583008
#  adversarial loss: 0.7590231895446777
#
# step: 900
#  discriminator loss: 0.7542718648910522
#  adversarial loss: 0.7157250642776489
#
# step: 1000
#  discriminator loss: 0.6947838068008423
#  adversarial loss: 0.7415564060211182
#
# step: 1100
#  discriminator loss: 0.716923713684082
#  adversarial loss: 0.7376765012741089
#
# step: 1200
#  discriminator loss: 0.6943955421447754
#  adversarial loss: 0.7771035432815552
#
# step: 1300
#  discriminator loss: 0.7252686619758606
#  adversarial loss: 0.720020592212677
#
# step: 1400
#  discriminator loss: 0.6916479468345642
#  adversarial loss: 0.7354492545127869
#
# step: 1500
#  discriminator loss: 0.7078949809074402
#  adversarial loss: 0.7419318556785583
#
# step: 1600
#  discriminator loss: 0.661002516746521
#  adversarial loss: 5.038104057312012
#
# step: 1700
#  discriminator loss: 0.7051092386245728
#  adversarial loss: 0.7617994546890259
#
# step: 1800
#  discriminator loss: 0.729415774345398
#  adversarial loss: 0.7601575255393982
#
# step: 1900
#  discriminator loss: 0.6956897974014282
#  adversarial loss: 0.7079421877861023
#
# step: 2000
#  discriminator loss: 0.7076443433761597
#  adversarial loss: 0.7132928967475891
#
# step: 2100
#  discriminator loss: 0.6891323924064636
#  adversarial loss: 0.7592726349830627
#
# step: 2200
#  discriminator loss: 0.8781806230545044
#  adversarial loss: 0.7933123111724854
#
# step: 2300
#  discriminator loss: 0.6992599368095398
#  adversarial loss: 0.7345755696296692
#
# step: 2400
#  discriminator loss: 0.7232334017753601
#  adversarial loss: 0.7590206861495972
#
# step: 2500
#  discriminator loss: 0.698397159576416
#  adversarial loss: 0.9310572743415833
#
# step: 2600
#  discriminator loss: 0.6886106729507446
#  adversarial loss: 0.7605103254318237
#
# step: 2700
#  discriminator loss: 0.6985002756118774
#  adversarial loss: 0.7714351415634155
#
# step: 2800
#  discriminator loss: 0.7049269676208496
#  adversarial loss: 0.719971776008606
#
# step: 2900
#  discriminator loss: 0.703583836555481
#  adversarial loss: 0.7640200853347778
#
# step: 3000
#  discriminator loss: 0.689338207244873
#  adversarial loss: 0.7592552900314331
#
# step: 3100
#  discriminator loss: 0.6803132891654968
#  adversarial loss: 1.2676746845245361
#
# step: 3200
#  discriminator loss: 0.7106512784957886
#  adversarial loss: 0.8075989484786987
#
# step: 3300
#  discriminator loss: 0.6970189809799194
#  adversarial loss: 0.7930188179016113
#
# step: 3400
#  discriminator loss: 0.6933490037918091
#  adversarial loss: 0.8011767268180847
#
# step: 3500
#  discriminator loss: 0.693385660648346
#  adversarial loss: 0.7468842267990112
#
# step: 3600
#  discriminator loss: 0.688629686832428
#  adversarial loss: 0.6949371695518494
#
# step: 3700
#  discriminator loss: 0.6910654902458191
#  adversarial loss: 0.7623127102851868
#
# step: 3800
#  discriminator loss: 0.7211846113204956
#  adversarial loss: 0.7092652320861816
#
# step: 3900
#  discriminator loss: 0.7019115686416626
#  adversarial loss: 0.7965003252029419
#
# step: 4000
#  discriminator loss: 0.6957098245620728
#  adversarial loss: 0.7203662991523743
#
# step: 4100
#  discriminator loss: 0.6941519975662231
#  adversarial loss: 0.7629467248916626
#
# step: 4200
#  discriminator loss: 0.698026180267334
#  adversarial loss: 0.7255470752716064
#
# step: 4300
#  discriminator loss: 0.8262675404548645
#  adversarial loss: 0.6893727779388428
#
# step: 4400
#  discriminator loss: 0.6860617399215698
#  adversarial loss: 0.8007572293281555
#
# step: 4500
#  discriminator loss: 0.6972659230232239
#  adversarial loss: 0.7581968903541565
#
# step: 4600
#  discriminator loss: 0.6940735578536987
#  adversarial loss: 0.7202253341674805
#
# step: 4700
#  discriminator loss: 0.6897668838500977
#  adversarial loss: 0.903464138507843
#
# step: 4800
#  discriminator loss: 0.7040542364120483
#  adversarial loss: 0.7490541338920593
#
# step: 4900
#  discriminator loss: 0.6990262866020203
#  adversarial loss: 0.7392004132270813
#
# step: 5000
#  discriminator loss: 0.7161163091659546
#  adversarial loss: 0.763471245765686
#
# step: 5100
#  discriminator loss: 0.6951144933700562
#  adversarial loss: 0.7903094291687012
#
# step: 5200
#  discriminator loss: 0.6997584104537964
#  adversarial loss: 0.8142703175544739
#
# step: 5300
#  discriminator loss: 0.7061837911605835
#  adversarial loss: 0.7494423389434814
#
# step: 5400
#  discriminator loss: 0.7489215731620789
#  adversarial loss: 0.7903833985328674
#
# step: 5500
#  discriminator loss: 0.7089180946350098
#  adversarial loss: 0.6933172345161438
#
# step: 5600
#  discriminator loss: 0.6928684711456299
#  adversarial loss: 0.7539299726486206
#
# step: 5700
#  discriminator loss: 1.1225676536560059
#  adversarial loss: 0.8176794052124023
#
# step: 5800
#  discriminator loss: 0.7061325907707214
#  adversarial loss: 0.7587763071060181
#
# step: 5900
#  discriminator loss: 0.6931549310684204
#  adversarial loss: 0.7347801327705383
#
# step: 6000
#  discriminator loss: 0.7044051885604858
#  adversarial loss: 0.7607680559158325
#
# step: 6100
#  discriminator loss: 0.6941449046134949
#  adversarial loss: 0.7566763162612915
#
# step: 6200
#  discriminator loss: 0.7054107785224915
#  adversarial loss: 0.8063102960586548
#
# step: 6300
#  discriminator loss: 0.7044367790222168
#  adversarial loss: 1.0590282678604126
#
# step: 6400
#  discriminator loss: 0.6932298541069031
#  adversarial loss: 0.7620893716812134
#
# step: 6500
#  discriminator loss: 0.6933155059814453
#  adversarial loss: 0.7523618936538696
#
# step: 6600
#  discriminator loss: 0.6822415590286255
#  adversarial loss: 0.7583752274513245
#
# step: 6700
#  discriminator loss: 0.7037500739097595
#  adversarial loss: 0.7446157336235046
#
# step: 6800
#  discriminator loss: 0.697350263595581
#  adversarial loss: 0.798491358757019
#
# step: 6900
#  discriminator loss: 0.6880316734313965
#  adversarial loss: 0.7650543451309204
#
# step: 7000
#  discriminator loss: 0.6760409474372864
#  adversarial loss: 0.7585967779159546
#
# step: 7100
#  discriminator loss: 0.6863910555839539
#  adversarial loss: 0.7918899059295654
#
# step: 7200
#  discriminator loss: 0.6981282830238342
#  adversarial loss: 0.769476592540741
#
# step: 7300
#  discriminator loss: 0.6891867518424988
#  adversarial loss: 0.7752925753593445
#
# step: 7400
#  discriminator loss: 0.7020729780197144
#  adversarial loss: 0.7902292609214783
#
# step: 7500
#  discriminator loss: 0.6850383281707764
#  adversarial loss: 0.7566222548484802
#
# step: 7600
#  discriminator loss: 0.7104505896568298
#  adversarial loss: 0.799690842628479
#
# step: 7700
#  discriminator loss: 0.6872585415840149
#  adversarial loss: 0.7732000350952148
#
# step: 7800
#  discriminator loss: 0.6820566654205322
#  adversarial loss: 1.0369802713394165
#
# step: 7900
#  discriminator loss: 0.7190814018249512
#  adversarial loss: 0.6909810304641724
#
# step: 8000
#  discriminator loss: 0.692191481590271
#  adversarial loss: 0.7195367813110352
#
# step: 8100
#  discriminator loss: 0.6831963658332825
#  adversarial loss: 0.7364582419395447
#
# step: 8200
#  discriminator loss: 0.7050704956054688
#  adversarial loss: 0.7460290193557739
#
# step: 8300
#  discriminator loss: 0.674463152885437
#  adversarial loss: 0.7309224605560303
#
# step: 8400
#  discriminator loss: 0.6556695103645325
#  adversarial loss: 0.6511715650558472
#
# step: 8500
#  discriminator loss: 0.6662324666976929
#  adversarial loss: 0.7901831865310669
#
# step: 8600
#  discriminator loss: 0.6597773432731628
#  adversarial loss: 0.8306856155395508
#
# step: 8700
#  discriminator loss: 0.6899359822273254
#  adversarial loss: 0.7716436386108398
#
# step: 8800
#  discriminator loss: 0.6836358904838562
#  adversarial loss: 0.7808065414428711
#
# step: 8900
#  discriminator loss: 0.6976341605186462
#  adversarial loss: 0.8556450009346008
#
# step: 9000
#  discriminator loss: 0.6664206981658936
#  adversarial loss: 0.7700018286705017
#
# step: 9100
#  discriminator loss: 0.7269583940505981
#  adversarial loss: 0.7560378313064575
#
# step: 9200
#  discriminator loss: 0.7206865549087524
#  adversarial loss: 0.7189844846725464
#
# step: 9300
#  discriminator loss: 0.6626299023628235
#  adversarial loss: 0.7625406384468079
#
# step: 9400
#  discriminator loss: 0.692974865436554
#  adversarial loss: 0.750511646270752
#
# step: 9500
#  discriminator loss: 0.6865233182907104
#  adversarial loss: 0.7809893488883972
#
# step: 9600
#  discriminator loss: 0.6709883809089661
#  adversarial loss: 0.7977897524833679
#
# step: 9700
#  discriminator loss: 0.7172878980636597
#  adversarial loss: 0.7364519834518433
#
# step: 9800
#  discriminator loss: 0.6878049373626709
#  adversarial loss: 0.8101484179496765
#
# step: 9900
#  discriminator loss: 0.8081172704696655
#  adversarial loss: 0.5709182024002075

# %% [markdown]
# #### 이미지 생성을 통한 시각화

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - 잠재 공간에서 랜덤한 포인트를 샘플링

# %%
random_latent_vectors = np.random.normal(size = (10, latent_dim))

# %% [markdown]
# - 가짜 이미지로 디코딩

# %%
generated_images = generator.predict(random_latent_vectors)

# %%
print(generated_images.shape)
# Out:
# (10, 32, 32, 3)

# %%
plt.figure(figsize = (20,8))
for i in range(generated_images.shape[0]):
    plt.subplot(2, 5, i+1)
    img = image.array_to_img(generated_images[i] * 255., scale= False)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])

plt.show()
