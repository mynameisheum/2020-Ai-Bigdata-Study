# %% [markdown]
# # WaveNet: A generative model for raw audio
#
# * https://deepmind.com/blog/article/wavenet-generative-model-raw-audio
# * 참고: https://github.com/choyi0521/wavenet-pytorch

# %% [markdown]
# * WaveNet은 기존의 Text-to-Speech 시스템보다 더 자연스럽고 어떤 사람의 목소리를 흉내내는 스피치를 생성할 수 있다는 것을 보여줌
# * WaveNet은 PixelCNN 구조를 기반으로 한 오디오 생성 모델로 보다 자연스러운 음성 신호를 생성 가능
#
# ![](https://lh3.googleusercontent.com/XMJlFDtiFU7WtZYnPDMDhT6jTFEXvTpY7c7sY70PtTkzEIDm6DvUv5nvHHwbOrUrDckS34aIu5fiZx0615p1-nf3rFxzhza387ud=w1440-rw-v1)
#
# * 이후 Tacotron, WaveGlow 등 더욱 발전된 모델 개발의 기초가 됨

# %% [markdown]
# ## 오디오 데이터 준비

# %% [markdown]
# * 해당 예제에서는 LJspeech dataset을 사용
# * 데이터를 다운로드하기 위해 torchaudio를 설치
# * torchaudio를 활용해 LJspeech dataset을 다운로드
# * https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2

# %%
# !pip install torchaudio
# Out:
# Collecting torchaudio
#   Downloading https://files.pythonhosted.org/packages/3f/23/6b54106b3de029d3f10cf8debc302491c17630357449c900d6209665b302/torchaudio-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.6MB)
#      |████████████████████████████████| 7.6MB 6.9MB/s
# Requirement already satisfied: torch==1.7.0 in /usr/local/lib/python3.6/dist-packages (from torchaudio) (1.7.0+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch==1.7.0->torchaudio) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.7.0->torchaudio) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.7.0->torchaudio) (1.18.5)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch==1.7.0->torchaudio) (0.7)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.7.0

# %%
import torchaudio

LJSpeech_url = 'https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2'
train_dataset = torchaudio.datasets.LJSPEECH("", url=LJSpeech_url, download=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '
# HBox(children=(FloatProgress(value=0.0, max=2748572632.0), HTML(value='')))

# %% [markdown]
# ## 오디오 데이터 변환

# %% [markdown]
# * (de)quantize_signal은 데이터를 mu scale로 변환(원 상태로 변환)시켜줌

# %%
import numpy as np

def quantize_signal(data, n_class):
    mu_x = np.sign(data) * np.log(1 + n_class * np.abs(data)) / np.log(n_class + 1)
    bins = np.linspace(-1, 1, n_class)
    quantized_data = np.digitize(mu_x, bins) - 1
    return quantized_data

def dequantize_signal(data, n_class):
    data = (data / n_class) * 2. - 1
    s = np.sign(data) * (np.exp(np.abs(data) * np.log(n_class + 1)) - 1) / n_class
    return s

# %% [markdown]
# ## SpeechDataset

# %% [markdown]
# * data 사용을 편리하게 하기 위해 SpeechDataset 객체 정의
#   + create_dataset - 다운로드한 audio file을 처리해 dataset으로 구성
#   + init_dataset - 데이터셋의 각 항목들을 초기화함
#   + \_\_getitme__ - 데이터셋에서 데이터를 꺼낼 때 처리할 코드들을 명시한 함수

# %%
from torch.utils.data import Dataset
import numpy as np
import librosa
import random
import torch
import os

class SpeechDataset(Dataset):
    def __init__(self,
                 n_class,
                 slice_length,
                 frame_length,
                 frame_stride,
                 test_size,
                 device,
                 dataset_path='./dataset'):
        self.n_class = n_class
        self.slice_length = slice_length
        self.frame_length = frame_length
        self.frame_stride = frame_stride
        self.test_size = test_size
        self.device = device
        self.dataset_path = dataset_path

    def create_dataset(self, max_files, prefix=None):
        lj_path = './LJSpeech-1.1'
        wav_names = []
        with open(lj_path + '/metadata.csv', encoding='utf-8') as f:
            for line in f:
                name = line.split('|')[0]
                if prefix and name.split('-')[0] != prefix:
                    continue
                wav_names.append(line.split('|')[0])

        random.seed(42)
        random.shuffle(wav_names)
        wav_names = wav_names[:max_files]

        count = 0
        x, cond = None, None
        for wav_name in wav_names:
            wav_path = lj_path + '/wavs/' + wav_name + '.wav'

            # calculate log mel spectrum
            y, sr = librosa.core.load(wav_path)
            input_nfft = int(round(sr * self.frame_length))
            input_stride = int(round(sr * self.frame_stride))
            s = librosa.feature.melspectrogram(y=y, n_mels=N_MELS, n_fft=input_nfft, hop_length=input_stride)
            s = librosa.core.power_to_db(s, ref=np.max)

            # scale to [0, 1]
            s /= 80.0

            new_x = quantize_signal(y, self.n_class)
            new_cond = self.time_resolution(s, y.shape[0])
            print(wav_name, 'processed.')

            if x is None:
                x, cond = new_x, new_cond
            else:
                x, cond = np.concatenate((x, new_x)), np.column_stack((cond, new_cond))

            for i in range(0, x.shape[0]-self.slice_length+1, self.slice_length):
                np.save(self.dataset_path + '/x_' + str(count) + '.npy', x[i:i+self.slice_length])
                np.save(self.dataset_path + '/cond_' + str(count) + '.npy', cond[:, i:i+self.slice_length])
                count += 1

            if x.shape[0] % self.slice_length == 0:
                x, cond = None, None
            else:
                x, cond = x[-x.shape[0]%self.slice_length:], cond[:, -x.shape[0] % self.slice_length:]

    def init_dataset(self, test_mode):
        self.test_mode = test_mode
        file_list = os.listdir(self.dataset_path)
        tot = len(file_list)//2
        self.test_length = int(tot*self.test_size)
        self.train_length = tot-self.test_length

    def __len__(self):
        return self.test_length if self.test_mode else self.train_length

    def __getitem__(self, idx):
        if self.test_mode:
            idx += self.train_length
        x = np.load(self.dataset_path+'/x_'+str(idx)+'.npy')
        cond = np.load(self.dataset_path+'/cond_'+str(idx)+'.npy')

        # one hot encoding
        embedded_x = np.zeros((self.n_class, x.shape[0]))
        embedded_x[x, np.arange(x.shape[0])] = 1

        return torch.tensor(embedded_x[:, :-1], dtype=torch.float, device=self.device),\
               torch.tensor(x[1:], dtype=torch.long, device=self.device),\
               torch.tensor(cond[:, :-1], dtype=torch.float, device=self.device)

    def time_resolution(self, cond, target_length):
        z = np.zeros((cond.shape[0], target_length))
        repeated_cond = np.repeat(cond, target_length//cond.shape[1], axis=1)
        z[:, :repeated_cond.shape[1]] = repeated_cond
        return z

# %% [markdown]
# ## WaveNet 모델 구성

# %% [markdown]
# * WaveNet의 특징으론 Causal Conv와 Residual block, Skip connection이 존재

# %% [markdown]
# ![다운로드.png](data:image/png;base64,...)
#
# 출처 - https://hwiyong.tistory.com/293

# %%
import torch.nn as nn
import torch
import numpy as np

class WaveNet(nn.Module):
    def __init__(self, n_class, hidden_channels, cond_channels, n_repeat, n_layer, device):
        super(WaveNet, self).__init__()
        self.n_class = n_class
        self.hidden_channels = hidden_channels

        self.input_conv = nn.Conv1d(in_channels=n_class,
                                    out_channels=hidden_channels,
                                    kernel_size=1)
        self.filter_convs = nn.ModuleList()
        self.gate_convs = nn.ModuleList()
        self.cond_filter_convs = nn.ModuleList()
        self.cond_gate_convs = nn.ModuleList()
        self.residual_convs = nn.ModuleList()
        self.skip_convs = nn.ModuleList()
        self.dilations = []
        self.pad = []

        for _ in range(n_repeat):
            for i in range(n_layer):
                dilation = 2**i
                self.dilations.append(dilation)
                self.pad.append(nn.ConstantPad1d((dilation, 0), 0))
                self.filter_convs.append(nn.Conv1d(in_channels=hidden_channels,
                                                   out_channels=hidden_channels,
                                                   kernel_size=2,
                                                   dilation=dilation))
                self.gate_convs.append(nn.Conv1d(in_channels=hidden_channels,
                                                 out_channels=hidden_channels,
                                                 kernel_size=2,
                                                 dilation=dilation))
                self.cond_filter_convs.append(nn.Conv1d(in_channels=cond_channels,
                                                        out_channels=hidden_channels,
                                                        kernel_size=2,
                                                        dilation=dilation))
                self.cond_gate_convs.append(nn.Conv1d(in_channels=cond_channels,
                                                      out_channels=hidden_channels,
                                                      kernel_size=2,
                                                      dilation=dilation))
                self.residual_convs.append(nn.Conv1d(in_channels=hidden_channels,
                                                     out_channels=hidden_channels,
                                                     kernel_size=1))
                self.skip_convs.append(nn.Conv1d(in_channels=hidden_channels,
                                                 out_channels=hidden_channels,
                                                 kernel_size=1))


        self.output_conv1 = nn.Conv1d(in_channels=hidden_channels,
                                      out_channels=hidden_channels,
                                      kernel_size=1)
        self.output_conv2 = nn.Conv1d(in_channels=hidden_channels,
                                      out_channels=n_class,
                                      kernel_size=1)
        self.relu = nn.ReLU()


        self.max_dilation = max(self.dilations)
        self.device = device
        self.to(device)

    def forward(self, x, cond):
        x = self.input_conv(x)
        skip = torch.zeros((x.shape[0], self.hidden_channels, x.shape[2]),
                           dtype=torch.float,
                           device=self.device)

        for i, dilation in enumerate(self.dilations):
            padded_x = self.pad[i](x)
            padded_cond = self.pad[i](cond)
            fx = self.filter_convs[i](padded_x)
            gx = self.gate_convs[i](padded_x)
            fc = self.cond_filter_convs[i](padded_cond)
            gc = self.cond_gate_convs[i](padded_cond)
            z = torch.tanh(fx+fc)*torch.sigmoid(gx+gc)

            skip += self.skip_convs[i](z)
            x += self.residual_convs[i](z)

        y = self.relu(skip)
        y = self.output_conv1(y)
        y = self.relu(y)
        y = self.output_conv2(y)
        return y

    def generate(self, cond, max_length):
        x = torch.zeros((cond.shape[0], self.n_class, cond.shape[2]),
                            dtype=torch.float,
                            device=self.device)
        x[:, np.random.randint(self.n_class, size=cond.shape[0]), 0] = 1
        res = []
        for i in range(min(cond.shape[2], max_length)):
            y = self.forward(x[:, :, :i+1], cond[:, :, :i+1])
            if i+1 < cond.shape[1]:
                out = np.argmax(y[:, :, i].cpu().detach().numpy(), axis=1)
                x[:, out, i+1] = 1
                res.append(out)
        return np.column_stack(res)

# %% [markdown]
# ### Stack of Dilated Causal Conv layers

# %% [markdown]
# ![](https://blog.kakaocdn.net/dn/c7mIvp/btqFJcl0GE5/hmM9P73RfUFu4w8sD4GMSk/img.gif)

# %% [markdown]
# * stacked of dilated causal conv layer 구조는 conv layer를 각 층마다 쌓고 dilation을 지정, 다른 unit의 정보(= 이전 시점의 정보)도 받아들임
# * WaveNet 모델에서 Conv Layer들을 dilation을 지정해 쌓아 다른 unit의 정보를 얻는 것을 볼 수 있음
# * 각 층의 dilation은 보통 층의 개수를 $n$으로 가정, $2^n$으로 지정
# * 결국 stacked of dilated causal conv layer 구조는 이전 sequence 정보를 많이 활용하기 위해 사용

# %% [markdown]
# ### Residual and Skip connection

# %% [markdown]
# *   residual and skip connection은 이미지 인식(Resnet)에서 가장 처음 고안된 구조
# *   residual은 연산 완료 결과에 연산 전 입력을 더하는 것을 의미
# *   skip connection은 연산 결과를 다음 연산에 넘겨줄 뿐만 아니라, 최종 연산에도 전달하는 것을 의미
# *   residual and skip connection은 연산 과정에서 손실되는 원본의 정보를 보충해주는 역할
# *   결국 residual and skip connection은 더 심층적인 모델 학습을 가능하게 함

# %%
def forward(self, x, cond):
        x = self.input_conv(x)
        skip = torch.zeros((x.shape[0], self.hidden_channels, x.shape[2]),
                           dtype=torch.float,
                           device=self.device)

        for i, dilation in enumerate(self.dilations):
            padded_x = self.pad[i](x)
            padded_cond = self.pad[i](cond)
            fx = self.filter_convs[i](padded_x)
            gx = self.gate_convs[i](padded_x)
            fc = self.cond_filter_convs[i](padded_cond)
            gc = self.cond_gate_convs[i](padded_cond)
            z = torch.tanh(fx+fc)*torch.sigmoid(gx+gc)

            skip += self.skip_convs[i](z)
            x += self.residual_convs[i](z)

        y = self.relu(skip)
        y = self.output_conv1(y)
        y = self.relu(y)
        y = self.output_conv2(y)
        return y

# %%
# model
COND_CHANNELS = N_MELS
HIDDEN_CHANNELS = 128
N_REPEAT = 2
N_LAYER = 9

# %% [markdown]
# ## Trainer

# %% [markdown]
# * 학습을 편리하게 하기 위해 Trainer 객체 생성
#   + create_dataset - 앞서 구성한 dataset 객체를 생성하고 필요한 데이터를 구성
#   + train - 생성한 데이터를 바탕으로 모델을 통해 학습 진행
#   + validate - 평가 데이터를 바탕으로 모델에 대한 성능 평가 진행
#   + generate - 데이터를 입력받아 해당 데이터에 해당하는 wav 파일을 생성

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.nn.utils import clip_grad_norm_
import librosa
import os

class Trainer(object):
    def __init__(self):
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model = WaveNet(N_CLASS, HIDDEN_CHANNELS, COND_CHANNELS, N_REPEAT, N_LAYER, self.device)

        # training state
        self.sample_count = 0
        self.tot_steps = 0

    def create_dataset(self):
        dataset = SpeechDataset(N_CLASS, SLICE_LENGTH, FRAME_LENGTH, FRAME_STRIDE, TEST_SIZE, self.device)
        dataset.create_dataset(MAX_FILES, FILE_PREFIX)

    def train(self):
        self.model.train()
        dataset = SpeechDataset(N_CLASS, SLICE_LENGTH, FRAME_LENGTH, FRAME_STRIDE, TEST_SIZE, self.device)
        dataset.init_dataset(test_mode=False)
        data_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
        optimizer = torch.optim.Adam(self.model.parameters(), lr=LEARNING_RATE)
        for epoch in range(MAX_EPOCHS):
            for i, data in enumerate(data_loader):
                x, y, cond = data
                pred_y = self.model(x, cond)
                loss = F.cross_entropy(pred_y, y)
                optimizer.zero_grad()
                loss.backward()
                clip_grad_norm_(self.model.parameters(), MAX_NORM)
                optimizer.step()

                if i % PRINT_FREQ == 0:
                    print('epoch: %d, step:%d, tot_step:%d, loss: %f'%(epoch, i, self.tot_steps, loss.item()))
                if i % VALID_FREQ == 0:
                    self.validate()
                    self.model.eval()
                self.tot_steps += 1

    def validate(self):
        self.model.eval()
        dataset = SpeechDataset(N_CLASS, SLICE_LENGTH, FRAME_LENGTH, FRAME_STRIDE, TEST_SIZE, self.device)
        dataset.init_dataset(test_mode=True)
        data_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
        res = []
        for i, data in enumerate(data_loader):
            if i == MAX_VALID:
                break
            x, y, cond = data
            pred_y = self.model(x, cond)
            loss = F.cross_entropy(pred_y.squeeze(), y.squeeze())
            res.append(loss.item())
        print('valid loss: '+str(sum(res)/len(res)))

    def generate(self):
        self.model.eval()
        dataset = SpeechDataset(N_CLASS, SLICE_LENGTH, FRAME_LENGTH, FRAME_STRIDE, TEST_SIZE, self.device)
        dataset.init_dataset(test_mode=True)
        data_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
        for i, data in enumerate(data_loader):
            if i == MAX_GENERATE:
                break
            _, _, cond = data
            res = self.model.generate(cond, MAX_GENERATE_LENGTH)
            res = dequantize_signal(res, N_CLASS)
            for j in range(res.shape[0]):
                librosa.output.write_wav('./samples/sample%d.wav'%(self.sample_count), res[j], SAMPLE_RATE)
                self.sample_count += 1

# %% [markdown]
# *   data loader에서 사용되는 각 파라미터들을 정의
# *   각 파라미터에 대한 설명은 주석을 참조

# %%
N_CLASS = 256 # 양자화에 사용될 클래스 크기
FRAME_LENGTH = 0.025 # 프레임의 길이
FRAME_STRIDE = 0.010 # 프레임 간의 간격
N_MELS = 40 # melspectrogram 생성 시 크기
BATCHES = 100
SLICE_LENGTH = 8193 # 데이터를 자를때의 길이
TEST_SIZE = 0.1 # 성능 평가에 사용될 데이터셋의 크기 지정
FILE_PREFIX = 'LJ001'
MAX_FILES = 5 # 학습에 사용될 파일의 개수

# %% [markdown]
# *   학습때 필요한 파라미터들을 정의

# %%
# training
BATCH_SIZE = 4 
MAX_EPOCHS = 50
MAX_NORM = 4
LEARNING_RATE = 0.0001

PRINT_FREQ = 1
VALID_FREQ = 100
INFER_FREQ = 100
MAX_VALID = 1

# %% [markdown]
# *   생성때 필요한 파라미터들을 정의

# %%
# generate
MAX_GENERATE = 1
MAX_GENERATE_LENGTH = 4096
SAMPLE_RATE = 22050

# %%
1+1
# Out:
# 2

# %% [markdown]
# *   앞서 생성한 객체들을 구성해 학습 진행

# %%
tr = Trainer()

os.mkdir('./dataset')
os.mkdir('./samples')

tr.create_dataset()
tr.train()
# Out:
# LJ001-0003 processed.
# LJ001-0015 processed.
# LJ001-0126 processed.
# LJ001-0102 processed.
# LJ001-0150 processed.
# epoch: 0, step:0, tot_step:0, loss: 5.549261
# valid loss: 5.546250820159912
# epoch: 0, step:1, tot_step:1, loss: 5.543457
# epoch: 0, step:2, tot_step:2, loss: 5.540821
# epoch: 0, step:3, tot_step:3, loss: 5.541563
# epoch: 0, step:4, tot_step:4, loss: 5.538563
# epoch: 0, step:5, tot_step:5, loss: 5.539958
# epoch: 0, step:6, tot_step:6, loss: 5.521014
# epoch: 0, step:7, tot_step:7, loss: 5.529893
# epoch: 0, step:8, tot_step:8, loss: 5.526590
# epoch: 0, step:9, tot_step:9, loss: 5.524857
# epoch: 0, step:10, tot_step:10, loss: 5.530656
# epoch: 0, step:11, tot_step:11, loss: 5.527550
# epoch: 0, step:12, tot_step:12, loss: 5.518631
# epoch: 0, step:13, tot_step:13, loss: 5.526746
# epoch: 0, step:14, tot_step:14, loss: 5.514547
# epoch: 0, step:15, tot_step:15, loss: 5.516849
# epoch: 0, step:16, tot_step:16, loss: 5.507361
# epoch: 0, step:17, tot_step:17, loss: 5.523747
# epoch: 0, step:18, tot_step:18, loss: 5.516078
# epoch: 0, step:19, tot_step:19, loss: 5.495266
# epoch: 0, step:20, tot_step:20, loss: 5.506810
# epoch: 0, step:21, tot_step:21, loss: 5.505465
# epoch: 0, step:22, tot_step:22, loss: 5.509752
# epoch: 0, step:23, tot_step:23, loss: 5.494327
# epoch: 0, step:24, tot_step:24, loss: 5.496455
# epoch: 0, step:25, tot_step:25, loss: 5.481911
# epoch: 0, step:26, tot_step:26, loss: 5.485885
# epoch: 0, step:27, tot_step:27, loss: 5.480965
# epoch: 0, step:28, tot_step:28, loss: 5.504608
# epoch: 0, step:29, tot_step:29, loss: 5.501287
# epoch: 0, step:30, tot_step:30, loss: 5.499186
# epoch: 0, step:31, tot_step:31, loss: 5.491135
# epoch: 0, step:32, tot_step:32, loss: 5.489821
# epoch: 0, step:33, tot_step:33, loss: 5.455387
# epoch: 0, step:34, tot_step:34, loss: 5.481946
# epoch: 0, step:35, tot_step:35, loss: 5.491078
# epoch: 0, step:36, tot_step:36, loss: 5.490515
# epoch: 0, step:37, tot_step:37, loss: 5.469006
# epoch: 0, step:38, tot_step:38, loss: 5.469886
# epoch: 0, step:39, tot_step:39, loss: 5.469063
# epoch: 0, step:40, tot_step:40, loss: 5.426966
# epoch: 0, step:41, tot_step:41, loss: 5.447563
# epoch: 0, step:42, tot_step:42, loss: 5.482300
# epoch: 0, step:43, tot_step:43, loss: 5.459030
# epoch: 0, step:44, tot_step:44, loss: 5.480462
# epoch: 0, step:45, tot_step:45, loss: 5.466661
# epoch: 0, step:46, tot_step:46, loss: 5.421961
# epoch: 0, step:47, tot_step:47, loss: 5.438671
# epoch: 0, step:48, tot_step:48, loss: 5.432385
# epoch: 0, step:49, tot_step:49, loss: 5.427088
# epoch: 0, step:50, tot_step:50, loss: 5.399875
# epoch: 0, step:51, tot_step:51, loss: 5.455122
# epoch: 0, step:52, tot_step:52, loss: 5.472946
# epoch: 0, step:53, tot_step:53, loss: 5.390484
# epoch: 0, step:54, tot_step:54, loss: 5.370851
# epoch: 0, step:55, tot_step:55, loss: 5.399114
# epoch: 0, step:56, tot_step:56, loss: 5.375350
# epoch: 0, step:57, tot_step:57, loss: 5.393698
# epoch: 0, step:58, tot_step:58, loss: 5.372715
# epoch: 0, step:59, tot_step:59, loss: 5.377432
# epoch: 0, step:60, tot_step:60, loss: 5.428662
# epoch: 0, step:61, tot_step:61, loss: 5.345337
# epoch: 0, step:62, tot_step:62, loss: 5.294697
# epoch: 0, step:63, tot_step:63, loss: 5.393742
# epoch: 0, step:64, tot_step:64, loss: 5.427809
# epoch: 0, step:65, tot_step:65, loss: 5.356797
# epoch: 0, step:66, tot_step:66, loss: 5.326635
# epoch: 0, step:67, tot_step:67, loss: 5.340651
# epoch: 1, step:0, tot_step:68, loss: 5.312935
# valid loss: 5.3218536376953125
# epoch: 1, step:1, tot_step:69, loss: 5.488971
# epoch: 1, step:2, tot_step:70, loss: 5.238744
# epoch: 1, step:3, tot_step:71, loss: 5.252544
# epoch: 1, step:4, tot_step:72, loss: 5.322607
# epoch: 1, step:5, tot_step:73, loss: 5.270895
# epoch: 1, step:6, tot_step:74, loss: 5.380793
# epoch: 1, step:7, tot_step:75, loss: 5.316345
# epoch: 1, step:8, tot_step:76, loss: 5.306630
# epoch: 1, step:9, tot_step:77, loss: 5.391304
# epoch: 1, step:10, tot_step:78, loss: 5.296769
# epoch: 1, step:11, tot_step:79, loss: 5.327090
# epoch: 1, step:12, tot_step:80, loss: 5.283360
# epoch: 1, step:13, tot_step:81, loss: 5.205199
# epoch: 1, step:14, tot_step:82, loss: 5.263335
# epoch: 1, step:15, tot_step:83, loss: 5.140949
# epoch: 1, step:16, tot_step:84, loss: 5.335651
# epoch: 1, step:17, tot_step:85, loss: 5.377272
# epoch: 1, step:18, tot_step:86, loss: 5.279375
# epoch: 1, step:19, tot_step:87, loss: 5.173160
# epoch: 1, step:20, tot_step:88, loss: 5.277658
# epoch: 1, step:21, tot_step:89, loss: 5.308874
# epoch: 1, step:22, tot_step:90, loss: 5.325290
# epoch: 1, step:23, tot_step:91, loss: 5.339834
# epoch: 1, step:24, tot_step:92, loss: 5.372516
# epoch: 1, step:25, tot_step:93, loss: 5.358070
# epoch: 1, step:26, tot_step:94, loss: 5.342454
# epoch: 1, step:27, tot_step:95, loss: 5.215399
# epoch: 1, step:28, tot_step:96, loss: 5.254040
# epoch: 1, step:29, tot_step:97, loss: 5.287447
# epoch: 1, step:30, tot_step:98, loss: 5.314835
# epoch: 1, step:31, tot_step:99, loss: 5.182001
# epoch: 1, step:32, tot_step:100, loss: 5.229026
# epoch: 1, step:33, tot_step:101, loss: 5.170511
# epoch: 1, step:34, tot_step:102, loss: 5.193448
# epoch: 1, step:35, tot_step:103, loss: 5.130187
# epoch: 1, step:36, tot_step:104, loss: 5.221618
# epoch: 1, step:37, tot_step:105, loss: 5.224582
# epoch: 1, step:38, tot_step:106, loss: 5.188120
# epoch: 1, step:39, tot_step:107, loss: 5.241138
# epoch: 1, step:40, tot_step:108, loss: 5.232514
# epoch: 1, step:41, tot_step:109, loss: 5.088455
# epoch: 1, step:42, tot_step:110, loss: 5.239686
# epoch: 1, step:43, tot_step:111, loss: 5.282973
# epoch: 1, step:44, tot_step:112, loss: 5.068166
# epoch: 1, step:45, tot_step:113, loss: 5.029789
# epoch: 1, step:46, tot_step:114, loss: 5.259142
# epoch: 1, step:47, tot_step:115, loss: 5.143355
# epoch: 1, step:48, tot_step:116, loss: 5.266574
# epoch: 1, step:49, tot_step:117, loss: 5.042683
# epoch: 1, step:50, tot_step:118, loss: 5.148607
# epoch: 1, step:51, tot_step:119, loss: 5.030977
# epoch: 1, step:52, tot_step:120, loss: 5.052884
# epoch: 1, step:53, tot_step:121, loss: 5.207741
# epoch: 1, step:54, tot_step:122, loss: 4.965152
# epoch: 1, step:55, tot_step:123, loss: 5.202690
# epoch: 1, step:56, tot_step:124, loss: 4.947329
# epoch: 1, step:57, tot_step:125, loss: 5.230978
# epoch: 1, step:58, tot_step:126, loss: 4.898649
# epoch: 1, step:59, tot_step:127, loss: 5.199616
# epoch: 1, step:60, tot_step:128, loss: 4.921928
# epoch: 1, step:61, tot_step:129, loss: 5.235531
# epoch: 1, step:62, tot_step:130, loss: 5.224532
# epoch: 1, step:63, tot_step:131, loss: 5.217094
# epoch: 1, step:64, tot_step:132, loss: 5.197520
# epoch: 1, step:65, tot_step:133, loss: 4.955383
# epoch: 1, step:66, tot_step:134, loss: 5.220384
# epoch: 1, step:67, tot_step:135, loss: 4.662044
# epoch: 2, step:0, tot_step:136, loss: 5.139126
# valid loss: 5.049734592437744
# epoch: 2, step:1, tot_step:137, loss: 5.190580
# epoch: 2, step:2, tot_step:138, loss: 4.888732
# epoch: 2, step:3, tot_step:139, loss: 5.183682
# epoch: 2, step:4, tot_step:140, loss: 5.009488
# epoch: 2, step:5, tot_step:141, loss: 5.207404
# epoch: 2, step:6, tot_step:142, loss: 5.062867
# epoch: 2, step:7, tot_step:143, loss: 5.139860
# epoch: 2, step:8, tot_step:144, loss: 5.115245
# epoch: 2, step:9, tot_step:145, loss: 5.096695
# epoch: 2, step:10, tot_step:146, loss: 5.106301
# epoch: 2, step:11, tot_step:147, loss: 5.078113
# epoch: 2, step:12, tot_step:148, loss: 5.102326
# epoch: 2, step:13, tot_step:149, loss: 4.981847
# epoch: 2, step:14, tot_step:150, loss: 5.018270
# epoch: 2, step:15, tot_step:151, loss: 4.948294
# epoch: 2, step:16, tot_step:152, loss: 4.936374
# epoch: 2, step:17, tot_step:153, loss: 4.820711
# epoch: 2, step:18, tot_step:154, loss: 5.279161
# epoch: 2, step:19, tot_step:155, loss: 5.033087
# epoch: 2, step:20, tot_step:156, loss: 4.705925
# epoch: 2, step:21, tot_step:157, loss: 4.919237
# epoch: 2, step:22, tot_step:158, loss: 5.068819
# epoch: 2, step:23, tot_step:159, loss: 4.734801
# epoch: 2, step:24, tot_step:160, loss: 5.153539
# epoch: 2, step:25, tot_step:161, loss: 5.030946
# epoch: 2, step:26, tot_step:162, loss: 5.013224
# epoch: 2, step:27, tot_step:163, loss: 4.727262
# epoch: 2, step:28, tot_step:164, loss: 4.669524
# epoch: 2, step:29, tot_step:165, loss: 4.587259
# epoch: 2, step:30, tot_step:166, loss: 4.935107
# epoch: 2, step:31, tot_step:167, loss: 4.903741
# epoch: 2, step:32, tot_step:168, loss: 4.949948
# epoch: 2, step:33, tot_step:169, loss: 4.986989
# epoch: 2, step:34, tot_step:170, loss: 4.955953
# epoch: 2, step:35, tot_step:171, loss: 4.682048
# epoch: 2, step:36, tot_step:172, loss: 4.929516
# epoch: 2, step:37, tot_step:173, loss: 5.026906
# epoch: 2, step:38, tot_step:174, loss: 4.762018
# epoch: 2, step:39, tot_step:175, loss: 4.697317
# epoch: 2, step:40, tot_step:176, loss: 4.895713
# epoch: 2, step:41, tot_step:177, loss: 4.964650
# epoch: 2, step:42, tot_step:178, loss: 4.945792
# epoch: 2, step:43, tot_step:179, loss: 4.860781
# epoch: 2, step:44, tot_step:180, loss: 4.770954
# epoch: 2, step:45, tot_step:181, loss: 4.626818
# epoch: 2, step:46, tot_step:182, loss: 4.943881
# epoch: 2, step:47, tot_step:183, loss: 4.965609
# epoch: 2, step:48, tot_step:184, loss: 4.979884
# epoch: 2, step:49, tot_step:185, loss: 4.185592
# epoch: 2, step:50, tot_step:186, loss: 4.775153
# epoch: 2, step:51, tot_step:187, loss: 4.903629
# epoch: 2, step:52, tot_step:188, loss: 4.935730
# epoch: 2, step:53, tot_step:189, loss: 4.912282
# epoch: 2, step:54, tot_step:190, loss: 4.886699
# epoch: 2, step:55, tot_step:191, loss: 4.882701
# epoch: 2, step:56, tot_step:192, loss: 4.604997
# epoch: 2, step:57, tot_step:193, loss: 4.388432
# epoch: 2, step:58, tot_step:194, loss: 4.760839
# epoch: 2, step:59, tot_step:195, loss: 4.684614
# epoch: 2, step:60, tot_step:196, loss: 4.647115
# epoch: 2, step:61, tot_step:197, loss: 4.747397
# epoch: 2, step:62, tot_step:198, loss: 4.787449
# epoch: 2, step:63, tot_step:199, loss: 4.849577
# epoch: 2, step:64, tot_step:200, loss: 4.776388
# epoch: 2, step:65, tot_step:201, loss: 4.788399
# epoch: 2, step:66, tot_step:202, loss: 4.632831
# epoch: 2, step:67, tot_step:203, loss: 5.008556
# epoch: 3, step:0, tot_step:204, loss: 4.600986
# valid loss: 4.700867652893066
# epoch: 3, step:1, tot_step:205, loss: 4.317072
# epoch: 3, step:2, tot_step:206, loss: 4.724170
# epoch: 3, step:3, tot_step:207, loss: 4.765914
# epoch: 3, step:4, tot_step:208, loss: 4.531303
# epoch: 3, step:5, tot_step:209, loss: 4.745613
# epoch: 3, step:6, tot_step:210, loss: 4.748416
# epoch: 3, step:7, tot_step:211, loss: 4.748417
# epoch: 3, step:8, tot_step:212, loss: 4.739398
# epoch: 3, step:9, tot_step:213, loss: 4.836881
# epoch: 3, step:10, tot_step:214, loss: 4.567879
# epoch: 3, step:11, tot_step:215, loss: 4.772186
# epoch: 3, step:12, tot_step:216, loss: 4.531042
# epoch: 3, step:13, tot_step:217, loss: 4.719796
# epoch: 3, step:14, tot_step:218, loss: 4.299702
# epoch: 3, step:15, tot_step:219, loss: 4.741051
# epoch: 3, step:16, tot_step:220, loss: 4.677471
# epoch: 3, step:17, tot_step:221, loss: 4.675125
# epoch: 3, step:18, tot_step:222, loss: 4.367836
# epoch: 3, step:19, tot_step:223, loss: 4.749790
# epoch: 3, step:20, tot_step:224, loss: 4.722960
# epoch: 3, step:21, tot_step:225, loss: 4.593298
# epoch: 3, step:22, tot_step:226, loss: 4.726116
# epoch: 3, step:23, tot_step:227, loss: 4.541543
# epoch: 3, step:24, tot_step:228, loss: 4.484013
# epoch: 3, step:25, tot_step:229, loss: 4.513829
# epoch: 3, step:26, tot_step:230, loss: 4.395375
# epoch: 3, step:27, tot_step:231, loss: 4.573968
# epoch: 3, step:28, tot_step:232, loss: 4.581933
# epoch: 3, step:29, tot_step:233, loss: 4.648105
# epoch: 3, step:30, tot_step:234, loss: 4.681360
# epoch: 3, step:31, tot_step:235, loss: 4.628485
# epoch: 3, step:32, tot_step:236, loss: 4.649613
# epoch: 3, step:33, tot_step:237, loss: 4.614530
# epoch: 3, step:34, tot_step:238, loss: 4.393230
# epoch: 3, step:35, tot_step:239, loss: 4.578910
# epoch: 3, step:36, tot_step:240, loss: 4.540573
# epoch: 3, step:37, tot_step:241, loss: 4.401628
# epoch: 3, step:38, tot_step:242, loss: 4.579600
# epoch: 3, step:39, tot_step:243, loss: 4.719835
# epoch: 3, step:40, tot_step:244, loss: 4.588822
# epoch: 3, step:41, tot_step:245, loss: 4.610947
# epoch: 3, step:42, tot_step:246, loss: 4.745454
# epoch: 3, step:43, tot_step:247, loss: 4.287786
# epoch: 3, step:44, tot_step:248, loss: 4.520029
# epoch: 3, step:45, tot_step:249, loss: 4.588318
# epoch: 3, step:46, tot_step:250, loss: 4.585234
# epoch: 3, step:47, tot_step:251, loss: 4.651446
# epoch: 3, step:48, tot_step:252, loss: 4.274387
# epoch: 3, step:49, tot_step:253, loss: 4.404969
# epoch: 3, step:50, tot_step:254, loss: 4.643237
# epoch: 3, step:51, tot_step:255, loss: 4.698191
# epoch: 3, step:52, tot_step:256, loss: 4.621758
# epoch: 3, step:53, tot_step:257, loss: 4.463704
# epoch: 3, step:54, tot_step:258, loss: 4.504048
# epoch: 3, step:55, tot_step:259, loss: 4.432972
# epoch: 3, step:56, tot_step:260, loss: 4.528773
# epoch: 3, step:57, tot_step:261, loss: 4.633665
# epoch: 3, step:58, tot_step:262, loss: 4.471968
# epoch: 3, step:59, tot_step:263, loss: 4.386631
# epoch: 3, step:60, tot_step:264, loss: 4.507410
# epoch: 3, step:61, tot_step:265, loss: 4.598126
# epoch: 3, step:62, tot_step:266, loss: 4.549662
# epoch: 3, step:63, tot_step:267, loss: 4.528039
# epoch: 3, step:64, tot_step:268, loss: 4.416053
# epoch: 3, step:65, tot_step:269, loss: 4.543111
# epoch: 3, step:66, tot_step:270, loss: 4.448364
# epoch: 3, step:67, tot_step:271, loss: 4.379481
# epoch: 4, step:0, tot_step:272, loss: 4.688295
# valid loss: 4.448944091796875
# epoch: 4, step:1, tot_step:273, loss: 4.506876
# epoch: 4, step:2, tot_step:274, loss: 4.261851
# epoch: 4, step:3, tot_step:275, loss: 4.250445
# epoch: 4, step:4, tot_step:276, loss: 4.554158
# epoch: 4, step:5, tot_step:277, loss: 4.315111
# epoch: 4, step:6, tot_step:278, loss: 4.733397
# epoch: 4, step:7, tot_step:279, loss: 4.425464
# epoch: 4, step:8, tot_step:280, loss: 4.755518
# epoch: 4, step:9, tot_step:281, loss: 4.402796
# epoch: 4, step:10, tot_step:282, loss: 4.108370
# epoch: 4, step:11, tot_step:283, loss: 4.529651
# epoch: 4, step:12, tot_step:284, loss: 4.390149
# epoch: 4, step:13, tot_step:285, loss: 4.350998
# epoch: 4, step:14, tot_step:286, loss: 4.349425
# epoch: 4, step:15, tot_step:287, loss: 4.499874
# epoch: 4, step:16, tot_step:288, loss: 4.362458
# epoch: 4, step:17, tot_step:289, loss: 4.573418
# epoch: 4, step:18, tot_step:290, loss: 4.406297
# epoch: 4, step:19, tot_step:291, loss: 4.288904
# epoch: 4, step:20, tot_step:292, loss: 4.359656
# epoch: 4, step:21, tot_step:293, loss: 4.347824
# epoch: 4, step:22, tot_step:294, loss: 4.359877
# epoch: 4, step:23, tot_step:295, loss: 4.519711
# epoch: 4, step:24, tot_step:296, loss: 4.498051
# epoch: 4, step:25, tot_step:297, loss: 4.432096
# epoch: 4, step:26, tot_step:298, loss: 4.350800
# epoch: 4, step:27, tot_step:299, loss: 4.533028
# epoch: 4, step:28, tot_step:300, loss: 4.498649
# epoch: 4, step:29, tot_step:301, loss: 4.522586
# epoch: 4, step:30, tot_step:302, loss: 4.441810
# epoch: 4, step:31, tot_step:303, loss: 4.565279
# epoch: 4, step:32, tot_step:304, loss: 4.357653
# epoch: 4, step:33, tot_step:305, loss: 4.163160
# epoch: 4, step:34, tot_step:306, loss: 4.160524
# epoch: 4, step:35, tot_step:307, loss: 4.426174
# epoch: 4, step:36, tot_step:308, loss: 4.550296
# epoch: 4, step:37, tot_step:309, loss: 4.414824
# epoch: 4, step:38, tot_step:310, loss: 4.532152
# epoch: 4, step:39, tot_step:311, loss: 4.365708
# epoch: 4, step:40, tot_step:312, loss: 4.487723
# epoch: 4, step:41, tot_step:313, loss: 4.381454
# epoch: 4, step:42, tot_step:314, loss: 4.421770
# epoch: 4, step:43, tot_step:315, loss: 4.059090
# epoch: 4, step:44, tot_step:316, loss: 4.420019
# epoch: 4, step:45, tot_step:317, loss: 4.525778
# epoch: 4, step:46, tot_step:318, loss: 4.384214
# epoch: 4, step:47, tot_step:319, loss: 4.260600
# epoch: 4, step:48, tot_step:320, loss: 4.257929
# epoch: 4, step:49, tot_step:321, loss: 4.390822
# epoch: 4, step:50, tot_step:322, loss: 4.447089
# epoch: 4, step:51, tot_step:323, loss: 4.036319
# epoch: 4, step:52, tot_step:324, loss: 4.269736
# epoch: 4, step:53, tot_step:325, loss: 4.417541
# epoch: 4, step:54, tot_step:326, loss: 4.501051
# epoch: 4, step:55, tot_step:327, loss: 4.536041
# epoch: 4, step:56, tot_step:328, loss: 4.441327
# epoch: 4, step:57, tot_step:329, loss: 4.608384
# epoch: 4, step:58, tot_step:330, loss: 4.178807
# epoch: 4, step:59, tot_step:331, loss: 4.379293
# epoch: 4, step:60, tot_step:332, loss: 4.453505
# epoch: 4, step:61, tot_step:333, loss: 4.285907
# epoch: 4, step:62, tot_step:334, loss: 4.413627
# epoch: 4, step:63, tot_step:335, loss: 4.502255
# epoch: 4, step:64, tot_step:336, loss: 4.168005
# epoch: 4, step:65, tot_step:337, loss: 4.359470
# epoch: 4, step:66, tot_step:338, loss: 4.342753
# epoch: 4, step:67, tot_step:339, loss: 3.536083
# epoch: 5, step:0, tot_step:340, loss: 4.440300
# valid loss: 4.333543300628662
# epoch: 5, step:1, tot_step:341, loss: 4.160256
# epoch: 5, step:2, tot_step:342, loss: 4.162171
# epoch: 5, step:3, tot_step:343, loss: 4.366777
# epoch: 5, step:4, tot_step:344, loss: 4.154137
# epoch: 5, step:5, tot_step:345, loss: 4.392738
# epoch: 5, step:6, tot_step:346, loss: 4.135969
# epoch: 5, step:7, tot_step:347, loss: 4.266995
# epoch: 5, step:8, tot_step:348, loss: 4.432559
# epoch: 5, step:9, tot_step:349, loss: 4.237151
# epoch: 5, step:10, tot_step:350, loss: 4.456453
# epoch: 5, step:11, tot_step:351, loss: 4.273632
# epoch: 5, step:12, tot_step:352, loss: 4.365242
# epoch: 5, step:13, tot_step:353, loss: 4.614824
# epoch: 5, step:14, tot_step:354, loss: 4.370358
# epoch: 5, step:15, tot_step:355, loss: 4.262904
# epoch: 5, step:16, tot_step:356, loss: 4.345698
# epoch: 5, step:17, tot_step:357, loss: 4.420271
# epoch: 5, step:18, tot_step:358, loss: 4.294839
# epoch: 5, step:19, tot_step:359, loss: 4.252716
# epoch: 5, step:20, tot_step:360, loss: 4.356262
# epoch: 5, step:21, tot_step:361, loss: 4.335252
# epoch: 5, step:22, tot_step:362, loss: 4.211823
# epoch: 5, step:23, tot_step:363, loss: 4.483849
# epoch: 5, step:24, tot_step:364, loss: 4.401281
# epoch: 5, step:25, tot_step:365, loss: 4.492774
# epoch: 5, step:26, tot_step:366, loss: 4.195693
# epoch: 5, step:27, tot_step:367, loss: 4.179770
# epoch: 5, step:28, tot_step:368, loss: 4.489696
# epoch: 5, step:29, tot_step:369, loss: 4.224413
# epoch: 5, step:30, tot_step:370, loss: 4.323761
# epoch: 5, step:31, tot_step:371, loss: 4.044242
# epoch: 5, step:32, tot_step:372, loss: 4.447068
# epoch: 5, step:33, tot_step:373, loss: 4.063369
# epoch: 5, step:34, tot_step:374, loss: 4.403844
# epoch: 5, step:35, tot_step:375, loss: 4.275198
# epoch: 5, step:36, tot_step:376, loss: 4.403571
# epoch: 5, step:37, tot_step:377, loss: 4.245020
# epoch: 5, step:38, tot_step:378, loss: 4.178237
# epoch: 5, step:39, tot_step:379, loss: 4.276500
# epoch: 5, step:40, tot_step:380, loss: 4.366968
# epoch: 5, step:41, tot_step:381, loss: 4.119946
# epoch: 5, step:42, tot_step:382, loss: 4.376324
# epoch: 5, step:43, tot_step:383, loss: 4.092610
# epoch: 5, step:44, tot_step:384, loss: 4.507350
# epoch: 5, step:45, tot_step:385, loss: 4.392313
# epoch: 5, step:46, tot_step:386, loss: 4.280545
# epoch: 5, step:47, tot_step:387, loss: 4.512288
# epoch: 5, step:48, tot_step:388, loss: 4.082656
# epoch: 5, step:49, tot_step:389, loss: 4.015590
# epoch: 5, step:50, tot_step:390, loss: 4.504544
# epoch: 5, step:51, tot_step:391, loss: 4.170064
# epoch: 5, step:52, tot_step:392, loss: 4.148053
# epoch: 5, step:53, tot_step:393, loss: 4.337385
# epoch: 5, step:54, tot_step:394, loss: 4.259336
# epoch: 5, step:55, tot_step:395, loss: 4.223473
# epoch: 5, step:56, tot_step:396, loss: 4.204774
# epoch: 5, step:57, tot_step:397, loss: 4.377252
# epoch: 5, step:58, tot_step:398, loss: 4.280994
# epoch: 5, step:59, tot_step:399, loss: 4.396970
# epoch: 5, step:60, tot_step:400, loss: 4.118807
# epoch: 5, step:61, tot_step:401, loss: 4.270235
# epoch: 5, step:62, tot_step:402, loss: 4.294897
# epoch: 5, step:63, tot_step:403, loss: 3.696490
# epoch: 5, step:64, tot_step:404, loss: 4.136228
# epoch: 5, step:65, tot_step:405, loss: 4.101260
# epoch: 5, step:66, tot_step:406, loss: 4.085345
# epoch: 5, step:67, tot_step:407, loss: 4.123689
# epoch: 6, step:0, tot_step:408, loss: 4.037530
# valid loss: 4.214016914367676
# epoch: 6, step:1, tot_step:409, loss: 4.526638
# epoch: 6, step:2, tot_step:410, loss: 4.063570
# epoch: 6, step:3, tot_step:411, loss: 4.173478
# epoch: 6, step:4, tot_step:412, loss: 4.110301
# epoch: 6, step:5, tot_step:413, loss: 4.036711
# epoch: 6, step:6, tot_step:414, loss: 3.917109
# epoch: 6, step:7, tot_step:415, loss: 4.126559
# epoch: 6, step:8, tot_step:416, loss: 4.330863
# epoch: 6, step:9, tot_step:417, loss: 3.975541
# epoch: 6, step:10, tot_step:418, loss: 4.037395
# epoch: 6, step:11, tot_step:419, loss: 4.111994
# epoch: 6, step:12, tot_step:420, loss: 4.451976
# epoch: 6, step:13, tot_step:421, loss: 4.130375
# epoch: 6, step:14, tot_step:422, loss: 4.140294
# epoch: 6, step:15, tot_step:423, loss: 4.418869
# epoch: 6, step:16, tot_step:424, loss: 4.288601
# epoch: 6, step:17, tot_step:425, loss: 4.158095
# epoch: 6, step:18, tot_step:426, loss: 4.130787
# epoch: 6, step:19, tot_step:427, loss: 4.278408
# epoch: 6, step:20, tot_step:428, loss: 4.178712
# epoch: 6, step:21, tot_step:429, loss: 3.711171
# epoch: 6, step:22, tot_step:430, loss: 3.860092
# epoch: 6, step:23, tot_step:431, loss: 4.229038
# epoch: 6, step:24, tot_step:432, loss: 4.196594
# epoch: 6, step:25, tot_step:433, loss: 4.289584
# epoch: 6, step:26, tot_step:434, loss: 3.848029
# epoch: 6, step:27, tot_step:435, loss: 4.308849
# epoch: 6, step:28, tot_step:436, loss: 4.066613
# epoch: 6, step:29, tot_step:437, loss: 4.264024
# epoch: 6, step:30, tot_step:438, loss: 4.133706
# epoch: 6, step:31, tot_step:439, loss: 4.151621
# epoch: 6, step:32, tot_step:440, loss: 4.128265
# epoch: 6, step:33, tot_step:441, loss: 4.079451
# epoch: 6, step:34, tot_step:442, loss: 3.944518
# epoch: 6, step:35, tot_step:443, loss: 4.281232
# epoch: 6, step:36, tot_step:444, loss: 4.269091
# epoch: 6, step:37, tot_step:445, loss: 4.313292
# epoch: 6, step:38, tot_step:446, loss: 4.054188
# epoch: 6, step:39, tot_step:447, loss: 4.175882
# epoch: 6, step:40, tot_step:448, loss: 3.993245
# epoch: 6, step:41, tot_step:449, loss: 4.054590
# epoch: 6, step:42, tot_step:450, loss: 4.144654
# epoch: 6, step:43, tot_step:451, loss: 4.273504
# epoch: 6, step:44, tot_step:452, loss: 3.774651
# epoch: 6, step:45, tot_step:453, loss: 4.421267
# epoch: 6, step:46, tot_step:454, loss: 4.183561
# epoch: 6, step:47, tot_step:455, loss: 4.250141
# epoch: 6, step:48, tot_step:456, loss: 4.136848
# epoch: 6, step:49, tot_step:457, loss: 4.160287
# epoch: 6, step:50, tot_step:458, loss: 4.024259
# epoch: 6, step:51, tot_step:459, loss: 4.283743
# epoch: 6, step:52, tot_step:460, loss: 4.120596
# epoch: 6, step:53, tot_step:461, loss: 4.257941
# epoch: 6, step:54, tot_step:462, loss: 3.971109
# epoch: 6, step:55, tot_step:463, loss: 4.349167
# epoch: 6, step:56, tot_step:464, loss: 4.192100
# epoch: 6, step:57, tot_step:465, loss: 4.244552
# epoch: 6, step:58, tot_step:466, loss: 4.349921
# epoch: 6, step:59, tot_step:467, loss: 4.099187
# epoch: 6, step:60, tot_step:468, loss: 4.254167
# epoch: 6, step:61, tot_step:469, loss: 4.223612
# epoch: 6, step:62, tot_step:470, loss: 4.075875
# epoch: 6, step:63, tot_step:471, loss: 4.026041
# epoch: 6, step:64, tot_step:472, loss: 4.043454
# epoch: 6, step:65, tot_step:473, loss: 4.202644
# epoch: 6, step:66, tot_step:474, loss: 4.162388
# epoch: 6, step:67, tot_step:475, loss: 4.177693
# epoch: 7, step:0, tot_step:476, loss: 3.810460
# valid loss: 4.109353542327881
# epoch: 7, step:1, tot_step:477, loss: 3.873184
# epoch: 7, step:2, tot_step:478, loss: 4.143002
# epoch: 7, step:3, tot_step:479, loss: 4.086005
# epoch: 7, step:4, tot_step:480, loss: 4.167275
# epoch: 7, step:5, tot_step:481, loss: 4.113709
# epoch: 7, step:6, tot_step:482, loss: 4.173139
# epoch: 7, step:7, tot_step:483, loss: 3.806767
# epoch: 7, step:8, tot_step:484, loss: 4.319287
# epoch: 7, step:9, tot_step:485, loss: 4.021404
# epoch: 7, step:10, tot_step:486, loss: 4.133916
# epoch: 7, step:11, tot_step:487, loss: 3.847530
# epoch: 7, step:12, tot_step:488, loss: 3.928552
# epoch: 7, step:13, tot_step:489, loss: 4.041573
# epoch: 7, step:14, tot_step:490, loss: 4.102954
# epoch: 7, step:15, tot_step:491, loss: 4.191633
# epoch: 7, step:16, tot_step:492, loss: 3.983630
# epoch: 7, step:17, tot_step:493, loss: 4.119202
# epoch: 7, step:18, tot_step:494, loss: 4.145168
# epoch: 7, step:19, tot_step:495, loss: 4.138197
# epoch: 7, step:20, tot_step:496, loss: 4.187126
# epoch: 7, step:21, tot_step:497, loss: 4.146531
# epoch: 7, step:22, tot_step:498, loss: 3.996496
# epoch: 7, step:23, tot_step:499, loss: 4.141778
# epoch: 7, step:24, tot_step:500, loss: 4.345411
# epoch: 7, step:25, tot_step:501, loss: 4.056305
# epoch: 7, step:26, tot_step:502, loss: 4.276106
# epoch: 7, step:27, tot_step:503, loss: 4.186191
# epoch: 7, step:28, tot_step:504, loss: 3.835093
# epoch: 7, step:29, tot_step:505, loss: 4.048223
# epoch: 7, step:30, tot_step:506, loss: 3.881996
# epoch: 7, step:31, tot_step:507, loss: 4.355265
# epoch: 7, step:32, tot_step:508, loss: 4.111140
# epoch: 7, step:33, tot_step:509, loss: 4.327896
# epoch: 7, step:34, tot_step:510, loss: 3.919719
# epoch: 7, step:35, tot_step:511, loss: 4.043170
# epoch: 7, step:36, tot_step:512, loss: 4.164055
# epoch: 7, step:37, tot_step:513, loss: 4.138201
# epoch: 7, step:38, tot_step:514, loss: 4.070457
# epoch: 7, step:39, tot_step:515, loss: 4.201812
# epoch: 7, step:40, tot_step:516, loss: 4.012918
# epoch: 7, step:41, tot_step:517, loss: 4.233486
# epoch: 7, step:42, tot_step:518, loss: 3.899993
# epoch: 7, step:43, tot_step:519, loss: 3.940770
# epoch: 7, step:44, tot_step:520, loss: 4.153646
# epoch: 7, step:45, tot_step:521, loss: 3.860587
# epoch: 7, step:46, tot_step:522, loss: 4.238381
# epoch: 7, step:47, tot_step:523, loss: 3.883897
# epoch: 7, step:48, tot_step:524, loss: 4.340120
# epoch: 7, step:49, tot_step:525, loss: 4.024521
# epoch: 7, step:50, tot_step:526, loss: 3.891782
# epoch: 7, step:51, tot_step:527, loss: 3.499341
# epoch: 7, step:52, tot_step:528, loss: 3.992650
# epoch: 7, step:53, tot_step:529, loss: 3.881930
# epoch: 7, step:54, tot_step:530, loss: 4.049717
# epoch: 7, step:55, tot_step:531, loss: 3.908151
# epoch: 7, step:56, tot_step:532, loss: 4.258048
# epoch: 7, step:57, tot_step:533, loss: 4.233348
# epoch: 7, step:58, tot_step:534, loss: 4.420565
# epoch: 7, step:59, tot_step:535, loss: 4.132454
# epoch: 7, step:60, tot_step:536, loss: 4.055292
# epoch: 7, step:61, tot_step:537, loss: 4.098970
# epoch: 7, step:62, tot_step:538, loss: 4.036292
# epoch: 7, step:63, tot_step:539, loss: 3.742959
# epoch: 7, step:64, tot_step:540, loss: 3.945746
# epoch: 7, step:65, tot_step:541, loss: 4.073441
# epoch: 7, step:66, tot_step:542, loss: 3.621609
# epoch: 7, step:67, tot_step:543, loss: 3.889271
# epoch: 8, step:0, tot_step:544, loss: 4.184578
# valid loss: 4.043886184692383
# epoch: 8, step:1, tot_step:545, loss: 4.125943
# epoch: 8, step:2, tot_step:546, loss: 4.011451
# epoch: 8, step:3, tot_step:547, loss: 4.243694
# epoch: 8, step:4, tot_step:548, loss: 3.986900
# epoch: 8, step:5, tot_step:549, loss: 3.967967
# epoch: 8, step:6, tot_step:550, loss: 4.230906
# epoch: 8, step:7, tot_step:551, loss: 4.045327
# epoch: 8, step:8, tot_step:552, loss: 4.090280
# epoch: 8, step:9, tot_step:553, loss: 4.069798
# epoch: 8, step:10, tot_step:554, loss: 4.195984
# epoch: 8, step:11, tot_step:555, loss: 4.134490
# epoch: 8, step:12, tot_step:556, loss: 3.829280
# epoch: 8, step:13, tot_step:557, loss: 4.034143
# epoch: 8, step:14, tot_step:558, loss: 3.904104
# epoch: 8, step:15, tot_step:559, loss: 4.207451
# epoch: 8, step:16, tot_step:560, loss: 4.084286
# epoch: 8, step:17, tot_step:561, loss: 4.198192
# epoch: 8, step:18, tot_step:562, loss: 3.795050
# epoch: 8, step:19, tot_step:563, loss: 3.964545
# epoch: 8, step:20, tot_step:564, loss: 4.064389
# epoch: 8, step:21, tot_step:565, loss: 4.185952
# epoch: 8, step:22, tot_step:566, loss: 4.065443
# epoch: 8, step:23, tot_step:567, loss: 4.177083
# epoch: 8, step:24, tot_step:568, loss: 3.770407
# epoch: 8, step:25, tot_step:569, loss: 3.986037
# epoch: 8, step:26, tot_step:570, loss: 3.736808
# epoch: 8, step:27, tot_step:571, loss: 3.696245
# epoch: 8, step:28, tot_step:572, loss: 4.228475
# epoch: 8, step:29, tot_step:573, loss: 3.781846
# epoch: 8, step:30, tot_step:574, loss: 4.056637
# epoch: 8, step:31, tot_step:575, loss: 3.854943
# epoch: 8, step:32, tot_step:576, loss: 4.124169
# epoch: 8, step:33, tot_step:577, loss: 3.915161
# epoch: 8, step:34, tot_step:578, loss: 3.893302
# epoch: 8, step:35, tot_step:579, loss: 3.915228
# epoch: 8, step:36, tot_step:580, loss: 4.041792
# epoch: 8, step:37, tot_step:581, loss: 3.850311
# epoch: 8, step:38, tot_step:582, loss: 3.967823
# epoch: 8, step:39, tot_step:583, loss: 4.204260
# epoch: 8, step:40, tot_step:584, loss: 4.186307
# epoch: 8, step:41, tot_step:585, loss: 3.985991
# epoch: 8, step:42, tot_step:586, loss: 4.172258
# epoch: 8, step:43, tot_step:587, loss: 4.072847
# epoch: 8, step:44, tot_step:588, loss: 4.039159
# epoch: 8, step:45, tot_step:589, loss: 4.038579
# epoch: 8, step:46, tot_step:590, loss: 3.934434
# epoch: 8, step:47, tot_step:591, loss: 3.887672
# epoch: 8, step:48, tot_step:592, loss: 3.716098
# epoch: 8, step:49, tot_step:593, loss: 3.797156
# epoch: 8, step:50, tot_step:594, loss: 3.874360
# epoch: 8, step:51, tot_step:595, loss: 4.237736
# epoch: 8, step:52, tot_step:596, loss: 3.923672
# epoch: 8, step:53, tot_step:597, loss: 4.086686
# epoch: 8, step:54, tot_step:598, loss: 4.010151
# epoch: 8, step:55, tot_step:599, loss: 3.771074
# epoch: 8, step:56, tot_step:600, loss: 4.012407
# epoch: 8, step:57, tot_step:601, loss: 4.034625
# epoch: 8, step:58, tot_step:602, loss: 3.904625
# epoch: 8, step:59, tot_step:603, loss: 4.266130
# epoch: 8, step:60, tot_step:604, loss: 3.880886
# epoch: 8, step:61, tot_step:605, loss: 4.046158
# epoch: 8, step:62, tot_step:606, loss: 4.048056
# epoch: 8, step:63, tot_step:607, loss: 3.879102
# epoch: 8, step:64, tot_step:608, loss: 3.682294
# epoch: 8, step:65, tot_step:609, loss: 4.036978
# epoch: 8, step:66, tot_step:610, loss: 4.155109
# epoch: 8, step:67, tot_step:611, loss: 3.519701
# epoch: 9, step:0, tot_step:612, loss: 3.812199
# valid loss: 3.996985912322998
# epoch: 9, step:1, tot_step:613, loss: 4.072376
# epoch: 9, step:2, tot_step:614, loss: 3.829391
# epoch: 9, step:3, tot_step:615, loss: 3.855365
# epoch: 9, step:4, tot_step:616, loss: 4.016541
# epoch: 9, step:5, tot_step:617, loss: 3.862961
# epoch: 9, step:6, tot_step:618, loss: 3.864895
# epoch: 9, step:7, tot_step:619, loss: 3.813480
# epoch: 9, step:8, tot_step:620, loss: 4.014056
# epoch: 9, step:9, tot_step:621, loss: 3.704058
# epoch: 9, step:10, tot_step:622, loss: 3.921046
# epoch: 9, step:11, tot_step:623, loss: 4.058562
# epoch: 9, step:12, tot_step:624, loss: 3.832132
# epoch: 9, step:13, tot_step:625, loss: 3.845095
# epoch: 9, step:14, tot_step:626, loss: 4.196070
# epoch: 9, step:15, tot_step:627, loss: 4.099340
# epoch: 9, step:16, tot_step:628, loss: 4.144153
# epoch: 9, step:17, tot_step:629, loss: 4.054587
# epoch: 9, step:18, tot_step:630, loss: 3.825564
# epoch: 9, step:19, tot_step:631, loss: 3.958647
# epoch: 9, step:20, tot_step:632, loss: 4.021514
# epoch: 9, step:21, tot_step:633, loss: 3.923988
# epoch: 9, step:22, tot_step:634, loss: 4.013676
# epoch: 9, step:23, tot_step:635, loss: 4.111539
# epoch: 9, step:24, tot_step:636, loss: 4.195273
# epoch: 9, step:25, tot_step:637, loss: 4.189695
# epoch: 9, step:26, tot_step:638, loss: 4.021711
# epoch: 9, step:27, tot_step:639, loss: 4.028132
# epoch: 9, step:28, tot_step:640, loss: 4.007614
# epoch: 9, step:29, tot_step:641, loss: 4.007075
# epoch: 9, step:30, tot_step:642, loss: 3.708673
# epoch: 9, step:31, tot_step:643, loss: 3.985307
# epoch: 9, step:32, tot_step:644, loss: 4.067122
# epoch: 9, step:33, tot_step:645, loss: 3.880187
# epoch: 9, step:34, tot_step:646, loss: 3.942136
# epoch: 9, step:35, tot_step:647, loss: 4.023252
# epoch: 9, step:36, tot_step:648, loss: 3.869052
# epoch: 9, step:37, tot_step:649, loss: 3.848576
# epoch: 9, step:38, tot_step:650, loss: 3.855277
# epoch: 9, step:39, tot_step:651, loss: 3.685061
# epoch: 9, step:40, tot_step:652, loss: 3.732247
# epoch: 9, step:41, tot_step:653, loss: 3.894070
# epoch: 9, step:42, tot_step:654, loss: 3.820613
# epoch: 9, step:43, tot_step:655, loss: 4.024379
# epoch: 9, step:44, tot_step:656, loss: 3.771328
# epoch: 9, step:45, tot_step:657, loss: 3.864590
# epoch: 9, step:46, tot_step:658, loss: 4.218501
# epoch: 9, step:47, tot_step:659, loss: 4.099896
# epoch: 9, step:48, tot_step:660, loss: 4.102191
# epoch: 9, step:49, tot_step:661, loss: 3.948910
# epoch: 9, step:50, tot_step:662, loss: 3.983211
# epoch: 9, step:51, tot_step:663, loss: 3.747847
# epoch: 9, step:52, tot_step:664, loss: 3.793660
# epoch: 9, step:53, tot_step:665, loss: 3.799617
# epoch: 9, step:54, tot_step:666, loss: 4.002510
# epoch: 9, step:55, tot_step:667, loss: 3.659195
# epoch: 9, step:56, tot_step:668, loss: 4.129476
# epoch: 9, step:57, tot_step:669, loss: 4.253440
# epoch: 9, step:58, tot_step:670, loss: 3.845303
# epoch: 9, step:59, tot_step:671, loss: 4.176293
# epoch: 9, step:60, tot_step:672, loss: 3.783604
# epoch: 9, step:61, tot_step:673, loss: 3.530305
# epoch: 9, step:62, tot_step:674, loss: 4.092775
# epoch: 9, step:63, tot_step:675, loss: 3.992559
# epoch: 9, step:64, tot_step:676, loss: 4.041901
# epoch: 9, step:65, tot_step:677, loss: 4.124431
# epoch: 9, step:66, tot_step:678, loss: 4.100840
# epoch: 9, step:67, tot_step:679, loss: 4.070822
# epoch: 10, step:0, tot_step:680, loss: 3.941735
# valid loss: 4.028956413269043
# epoch: 10, step:1, tot_step:681, loss: 3.920244
# epoch: 10, step:2, tot_step:682, loss: 3.950777
# epoch: 10, step:3, tot_step:683, loss: 4.251393
# epoch: 10, step:4, tot_step:684, loss: 4.167831
# epoch: 10, step:5, tot_step:685, loss: 3.957614
# epoch: 10, step:6, tot_step:686, loss: 4.184495
# epoch: 10, step:7, tot_step:687, loss: 4.230692
# epoch: 10, step:8, tot_step:688, loss: 3.968319
# epoch: 10, step:9, tot_step:689, loss: 3.910436
# epoch: 10, step:10, tot_step:690, loss: 3.922398
# epoch: 10, step:11, tot_step:691, loss: 3.936013
# epoch: 10, step:12, tot_step:692, loss: 3.948403
# epoch: 10, step:13, tot_step:693, loss: 3.770696
# epoch: 10, step:14, tot_step:694, loss: 4.132457
# epoch: 10, step:15, tot_step:695, loss: 3.699958
# epoch: 10, step:16, tot_step:696, loss: 3.559710
# epoch: 10, step:17, tot_step:697, loss: 4.057730
# epoch: 10, step:18, tot_step:698, loss: 3.956306
# epoch: 10, step:19, tot_step:699, loss: 3.687393
# epoch: 10, step:20, tot_step:700, loss: 4.105752
# epoch: 10, step:21, tot_step:701, loss: 3.759232
# epoch: 10, step:22, tot_step:702, loss: 3.794461
# epoch: 10, step:23, tot_step:703, loss: 3.876033
# epoch: 10, step:24, tot_step:704, loss: 3.772996
# epoch: 10, step:25, tot_step:705, loss: 3.779350
# epoch: 10, step:26, tot_step:706, loss: 4.062938
# epoch: 10, step:27, tot_step:707, loss: 4.025366
# epoch: 10, step:28, tot_step:708, loss: 3.930222
# epoch: 10, step:29, tot_step:709, loss: 3.701454
# epoch: 10, step:30, tot_step:710, loss: 3.932075
# epoch: 10, step:31, tot_step:711, loss: 3.724253
# epoch: 10, step:32, tot_step:712, loss: 3.846748
# epoch: 10, step:33, tot_step:713, loss: 3.863687
# epoch: 10, step:34, tot_step:714, loss: 4.048038
# epoch: 10, step:35, tot_step:715, loss: 4.021164
# epoch: 10, step:36, tot_step:716, loss: 4.065917
# epoch: 10, step:37, tot_step:717, loss: 4.243111
# epoch: 10, step:38, tot_step:718, loss: 3.981095
# epoch: 10, step:39, tot_step:719, loss: 4.145782
# epoch: 10, step:40, tot_step:720, loss: 3.868241
# epoch: 10, step:41, tot_step:721, loss: 3.988171
# epoch: 10, step:42, tot_step:722, loss: 3.919747
# epoch: 10, step:43, tot_step:723, loss: 3.612615
# epoch: 10, step:44, tot_step:724, loss: 3.871929
# epoch: 10, step:45, tot_step:725, loss: 4.204327
# epoch: 10, step:46, tot_step:726, loss: 3.797697
# epoch: 10, step:47, tot_step:727, loss: 3.950260
# epoch: 10, step:48, tot_step:728, loss: 4.117866
# epoch: 10, step:49, tot_step:729, loss: 3.601833
# epoch: 10, step:50, tot_step:730, loss: 4.096935
# epoch: 10, step:51, tot_step:731, loss: 3.983599
# epoch: 10, step:52, tot_step:732, loss: 3.724580
# epoch: 10, step:53, tot_step:733, loss: 3.943940
# epoch: 10, step:54, tot_step:734, loss: 3.863995
# epoch: 10, step:55, tot_step:735, loss: 3.781911
# epoch: 10, step:56, tot_step:736, loss: 3.886887
# epoch: 10, step:57, tot_step:737, loss: 3.665801
# epoch: 10, step:58, tot_step:738, loss: 3.704179
# epoch: 10, step:59, tot_step:739, loss: 3.952457
# epoch: 10, step:60, tot_step:740, loss: 3.669947
# epoch: 10, step:61, tot_step:741, loss: 3.791548
# epoch: 10, step:62, tot_step:742, loss: 3.765627
# epoch: 10, step:63, tot_step:743, loss: 4.050528
# epoch: 10, step:64, tot_step:744, loss: 3.985927
# epoch: 10, step:65, tot_step:745, loss: 3.967361
# epoch: 10, step:66, tot_step:746, loss: 4.033592
# epoch: 10, step:67, tot_step:747, loss: 3.084660
# epoch: 11, step:0, tot_step:748, loss: 3.612482
# valid loss: 3.9092495441436768
# epoch: 11, step:1, tot_step:749, loss: 3.837719
# epoch: 11, step:2, tot_step:750, loss: 3.865095
# epoch: 11, step:3, tot_step:751, loss: 3.843583
# epoch: 11, step:4, tot_step:752, loss: 3.853378
# epoch: 11, step:5, tot_step:753, loss: 3.692868
# epoch: 11, step:6, tot_step:754, loss: 4.066599
# epoch: 11, step:7, tot_step:755, loss: 3.921160
# epoch: 11, step:8, tot_step:756, loss: 3.956593
# epoch: 11, step:9, tot_step:757, loss: 3.919215
# epoch: 11, step:10, tot_step:758, loss: 4.062943
# epoch: 11, step:11, tot_step:759, loss: 3.482830
# epoch: 11, step:12, tot_step:760, loss: 4.014319
# epoch: 11, step:13, tot_step:761, loss: 3.441794
# epoch: 11, step:14, tot_step:762, loss: 4.117302
# epoch: 11, step:15, tot_step:763, loss: 3.894998
# epoch: 11, step:16, tot_step:764, loss: 3.921501
# epoch: 11, step:17, tot_step:765, loss: 4.073205
# epoch: 11, step:18, tot_step:766, loss: 3.684553
# epoch: 11, step:19, tot_step:767, loss: 3.807495
# epoch: 11, step:20, tot_step:768, loss: 3.879341
# epoch: 11, step:21, tot_step:769, loss: 3.790514
# epoch: 11, step:22, tot_step:770, loss: 4.196203
# epoch: 11, step:23, tot_step:771, loss: 3.893703
# epoch: 11, step:24, tot_step:772, loss: 3.824983
# epoch: 11, step:25, tot_step:773, loss: 3.970901
# epoch: 11, step:26, tot_step:774, loss: 3.993494
# epoch: 11, step:27, tot_step:775, loss: 3.982111
# epoch: 11, step:28, tot_step:776, loss: 4.003888
# epoch: 11, step:29, tot_step:777, loss: 3.653454
# epoch: 11, step:30, tot_step:778, loss: 3.889621
# epoch: 11, step:31, tot_step:779, loss: 4.065874
# epoch: 11, step:32, tot_step:780, loss: 3.723860
# epoch: 11, step:33, tot_step:781, loss: 3.847609
# epoch: 11, step:34, tot_step:782, loss: 4.193723
# epoch: 11, step:35, tot_step:783, loss: 3.724159
# epoch: 11, step:36, tot_step:784, loss: 3.759765
# epoch: 11, step:37, tot_step:785, loss: 4.187910
# epoch: 11, step:38, tot_step:786, loss: 4.076531
# epoch: 11, step:39, tot_step:787, loss: 3.999475
# epoch: 11, step:40, tot_step:788, loss: 3.770216
# epoch: 11, step:41, tot_step:789, loss: 3.819221
# epoch: 11, step:42, tot_step:790, loss: 3.708771
# epoch: 11, step:43, tot_step:791, loss: 3.635803
# epoch: 11, step:44, tot_step:792, loss: 3.927819
# epoch: 11, step:45, tot_step:793, loss: 3.960150
# epoch: 11, step:46, tot_step:794, loss: 4.009305
# epoch: 11, step:47, tot_step:795, loss: 3.962300
# epoch: 11, step:48, tot_step:796, loss: 3.883232
# epoch: 11, step:49, tot_step:797, loss: 4.200266
# epoch: 11, step:50, tot_step:798, loss: 3.765408
# epoch: 11, step:51, tot_step:799, loss: 3.585098
# epoch: 11, step:52, tot_step:800, loss: 3.754392
# epoch: 11, step:53, tot_step:801, loss: 4.099812
# epoch: 11, step:54, tot_step:802, loss: 3.810692
# epoch: 11, step:55, tot_step:803, loss: 4.029063
# epoch: 11, step:56, tot_step:804, loss: 3.933785
# epoch: 11, step:57, tot_step:805, loss: 3.453449
# epoch: 11, step:58, tot_step:806, loss: 4.230402
# epoch: 11, step:59, tot_step:807, loss: 3.983407
# epoch: 11, step:60, tot_step:808, loss: 3.974990
# epoch: 11, step:61, tot_step:809, loss: 3.832586
# epoch: 11, step:62, tot_step:810, loss: 3.600640
# epoch: 11, step:63, tot_step:811, loss: 3.853098
# epoch: 11, step:64, tot_step:812, loss: 4.015422
# epoch: 11, step:65, tot_step:813, loss: 3.822597
# epoch: 11, step:66, tot_step:814, loss: 3.943935
# epoch: 11, step:67, tot_step:815, loss: 3.849862
# epoch: 12, step:0, tot_step:816, loss: 4.014673
# valid loss: 3.8999338150024414
# epoch: 12, step:1, tot_step:817, loss: 4.127132
# epoch: 12, step:2, tot_step:818, loss: 3.767533
# epoch: 12, step:3, tot_step:819, loss: 3.918268
# epoch: 12, step:4, tot_step:820, loss: 4.056415
# epoch: 12, step:5, tot_step:821, loss: 4.093227
# epoch: 12, step:6, tot_step:822, loss: 3.716229
# epoch: 12, step:7, tot_step:823, loss: 3.906531
# epoch: 12, step:8, tot_step:824, loss: 3.982426
# epoch: 12, step:9, tot_step:825, loss: 3.777775
# epoch: 12, step:10, tot_step:826, loss: 4.151933
# epoch: 12, step:11, tot_step:827, loss: 4.112782
# epoch: 12, step:12, tot_step:828, loss: 3.614788
# epoch: 12, step:13, tot_step:829, loss: 3.698679
# epoch: 12, step:14, tot_step:830, loss: 3.485794
# epoch: 12, step:15, tot_step:831, loss: 4.018783
# epoch: 12, step:16, tot_step:832, loss: 3.576212
# epoch: 12, step:17, tot_step:833, loss: 3.813459
# epoch: 12, step:18, tot_step:834, loss: 3.881915
# epoch: 12, step:19, tot_step:835, loss: 3.972708
# epoch: 12, step:20, tot_step:836, loss: 4.352960
# epoch: 12, step:21, tot_step:837, loss: 3.761290
# epoch: 12, step:22, tot_step:838, loss: 3.755919
# epoch: 12, step:23, tot_step:839, loss: 3.684057
# epoch: 12, step:24, tot_step:840, loss: 3.670827
# epoch: 12, step:25, tot_step:841, loss: 3.863887
# epoch: 12, step:26, tot_step:842, loss: 4.100524
# epoch: 12, step:27, tot_step:843, loss: 3.823967
# epoch: 12, step:28, tot_step:844, loss: 3.655249
# epoch: 12, step:29, tot_step:845, loss: 3.681511
# epoch: 12, step:30, tot_step:846, loss: 3.624278
# epoch: 12, step:31, tot_step:847, loss: 3.783073
# epoch: 12, step:32, tot_step:848, loss: 3.715478
# epoch: 12, step:33, tot_step:849, loss: 4.057821
# epoch: 12, step:34, tot_step:850, loss: 4.135109
# epoch: 12, step:35, tot_step:851, loss: 3.790404
# epoch: 12, step:36, tot_step:852, loss: 4.126328
# epoch: 12, step:37, tot_step:853, loss: 3.917120
# epoch: 12, step:38, tot_step:854, loss: 3.995224
# epoch: 12, step:39, tot_step:855, loss: 4.074618
# epoch: 12, step:40, tot_step:856, loss: 3.846448
# epoch: 12, step:41, tot_step:857, loss: 4.106218
# epoch: 12, step:42, tot_step:858, loss: 3.981128
# epoch: 12, step:43, tot_step:859, loss: 4.114610
# epoch: 12, step:44, tot_step:860, loss: 4.017228
# epoch: 12, step:45, tot_step:861, loss: 3.678383
# epoch: 12, step:46, tot_step:862, loss: 3.828736
# epoch: 12, step:47, tot_step:863, loss: 3.667936
# epoch: 12, step:48, tot_step:864, loss: 3.634887
# epoch: 12, step:49, tot_step:865, loss: 3.925926
# epoch: 12, step:50, tot_step:866, loss: 3.945210
# epoch: 12, step:51, tot_step:867, loss: 3.562475
# epoch: 12, step:52, tot_step:868, loss: 3.657325
# epoch: 12, step:53, tot_step:869, loss: 3.855115
# epoch: 12, step:54, tot_step:870, loss: 3.911577
# epoch: 12, step:55, tot_step:871, loss: 4.066845
# epoch: 12, step:56, tot_step:872, loss: 3.975658
# epoch: 12, step:57, tot_step:873, loss: 3.678436
# epoch: 12, step:58, tot_step:874, loss: 4.077373
# epoch: 12, step:59, tot_step:875, loss: 4.205009
# epoch: 12, step:60, tot_step:876, loss: 3.635015
# epoch: 12, step:61, tot_step:877, loss: 3.717583
# epoch: 12, step:62, tot_step:878, loss: 3.559568
# epoch: 12, step:63, tot_step:879, loss: 3.932790
# epoch: 12, step:64, tot_step:880, loss: 3.989264
# epoch: 12, step:65, tot_step:881, loss: 3.831932
# epoch: 12, step:66, tot_step:882, loss: 3.815399
# epoch: 12, step:67, tot_step:883, loss: 3.488646
# epoch: 13, step:0, tot_step:884, loss: 3.954964
# valid loss: 3.907379627227783
# epoch: 13, step:1, tot_step:885, loss: 3.858835
# epoch: 13, step:2, tot_step:886, loss: 3.940558
# epoch: 13, step:3, tot_step:887, loss: 3.865073
# epoch: 13, step:4, tot_step:888, loss: 3.987401
# epoch: 13, step:5, tot_step:889, loss: 3.681346
# epoch: 13, step:6, tot_step:890, loss: 3.923866
# epoch: 13, step:7, tot_step:891, loss: 3.971769
# epoch: 13, step:8, tot_step:892, loss: 3.564305
# epoch: 13, step:9, tot_step:893, loss: 3.874347
# epoch: 13, step:10, tot_step:894, loss: 4.002781
# epoch: 13, step:11, tot_step:895, loss: 3.805700
# epoch: 13, step:12, tot_step:896, loss: 3.905315
# epoch: 13, step:13, tot_step:897, loss: 3.903633
# epoch: 13, step:14, tot_step:898, loss: 3.600204
# epoch: 13, step:15, tot_step:899, loss: 3.613021
# epoch: 13, step:16, tot_step:900, loss: 3.819079
# epoch: 13, step:17, tot_step:901, loss: 3.750360
# epoch: 13, step:18, tot_step:902, loss: 3.957062
# epoch: 13, step:19, tot_step:903, loss: 4.005049
# epoch: 13, step:20, tot_step:904, loss: 3.506591
# epoch: 13, step:21, tot_step:905, loss: 3.792956
# epoch: 13, step:22, tot_step:906, loss: 3.908879
# epoch: 13, step:23, tot_step:907, loss: 3.861360
# epoch: 13, step:24, tot_step:908, loss: 3.750326
# epoch: 13, step:25, tot_step:909, loss: 3.937641
# epoch: 13, step:26, tot_step:910, loss: 3.983876
# epoch: 13, step:27, tot_step:911, loss: 3.810034
# epoch: 13, step:28, tot_step:912, loss: 4.119353
# epoch: 13, step:29, tot_step:913, loss: 3.751253
# epoch: 13, step:30, tot_step:914, loss: 3.976474
# epoch: 13, step:31, tot_step:915, loss: 3.913036
# epoch: 13, step:32, tot_step:916, loss: 3.984734
# epoch: 13, step:33, tot_step:917, loss: 4.190777
# epoch: 13, step:34, tot_step:918, loss: 3.963367
# epoch: 13, step:35, tot_step:919, loss: 3.915374
# epoch: 13, step:36, tot_step:920, loss: 3.665877
# epoch: 13, step:37, tot_step:921, loss: 4.029742
# epoch: 13, step:38, tot_step:922, loss: 3.980313
# epoch: 13, step:39, tot_step:923, loss: 4.109726
# epoch: 13, step:40, tot_step:924, loss: 4.007743
# epoch: 13, step:41, tot_step:925, loss: 4.082324
# epoch: 13, step:42, tot_step:926, loss: 3.926174
# epoch: 13, step:43, tot_step:927, loss: 3.787236
# epoch: 13, step:44, tot_step:928, loss: 3.558397
# epoch: 13, step:45, tot_step:929, loss: 4.044827
# epoch: 13, step:46, tot_step:930, loss: 3.258264
# epoch: 13, step:47, tot_step:931, loss: 3.821002
# epoch: 13, step:48, tot_step:932, loss: 3.962558
# epoch: 13, step:49, tot_step:933, loss: 4.053335
# epoch: 13, step:50, tot_step:934, loss: 3.985561
# epoch: 13, step:51, tot_step:935, loss: 3.753882
# epoch: 13, step:52, tot_step:936, loss: 3.226552
# epoch: 13, step:53, tot_step:937, loss: 3.978633
# epoch: 13, step:54, tot_step:938, loss: 3.881940
# epoch: 13, step:55, tot_step:939, loss: 3.587029
# epoch: 13, step:56, tot_step:940, loss: 3.655242
# epoch: 13, step:57, tot_step:941, loss: 3.978961
# epoch: 13, step:58, tot_step:942, loss: 3.852624
# epoch: 13, step:59, tot_step:943, loss: 3.940194
# epoch: 13, step:60, tot_step:944, loss: 4.041776
# epoch: 13, step:61, tot_step:945, loss: 3.933547
# epoch: 13, step:62, tot_step:946, loss: 3.910357
# epoch: 13, step:63, tot_step:947, loss: 3.824297
# epoch: 13, step:64, tot_step:948, loss: 4.104577
# epoch: 13, step:65, tot_step:949, loss: 4.043175
# epoch: 13, step:66, tot_step:950, loss: 3.897637
# epoch: 13, step:67, tot_step:951, loss: 3.912074
# epoch: 14, step:0, tot_step:952, loss: 3.985013
# valid loss: 3.839200019836426
# epoch: 14, step:1, tot_step:953, loss: 3.902258
# epoch: 14, step:2, tot_step:954, loss: 4.103466
# epoch: 14, step:3, tot_step:955, loss: 4.082309
# epoch: 14, step:4, tot_step:956, loss: 3.516434
# epoch: 14, step:5, tot_step:957, loss: 3.631799
# epoch: 14, step:6, tot_step:958, loss: 3.792558
# epoch: 14, step:7, tot_step:959, loss: 4.080299
# epoch: 14, step:8, tot_step:960, loss: 3.825915
# epoch: 14, step:9, tot_step:961, loss: 4.124097
# epoch: 14, step:10, tot_step:962, loss: 3.776227
# epoch: 14, step:11, tot_step:963, loss: 4.005865
# epoch: 14, step:12, tot_step:964, loss: 3.804163
# epoch: 14, step:13, tot_step:965, loss: 3.997123
# epoch: 14, step:14, tot_step:966, loss: 3.945428
# epoch: 14, step:15, tot_step:967, loss: 3.624365
# epoch: 14, step:16, tot_step:968, loss: 3.730359
# epoch: 14, step:17, tot_step:969, loss: 3.960012
# epoch: 14, step:18, tot_step:970, loss: 4.223187
# epoch: 14, step:19, tot_step:971, loss: 3.974245
# epoch: 14, step:20, tot_step:972, loss: 3.882351
# epoch: 14, step:21, tot_step:973, loss: 3.846247
# epoch: 14, step:22, tot_step:974, loss: 3.889273
# epoch: 14, step:23, tot_step:975, loss: 4.050144
# epoch: 14, step:24, tot_step:976, loss: 3.725244
# epoch: 14, step:25, tot_step:977, loss: 3.687924
# epoch: 14, step:26, tot_step:978, loss: 3.805919
# epoch: 14, step:27, tot_step:979, loss: 3.498648
# epoch: 14, step:28, tot_step:980, loss: 3.802301
# epoch: 14, step:29, tot_step:981, loss: 3.669148
# epoch: 14, step:30, tot_step:982, loss: 3.642493
# epoch: 14, step:31, tot_step:983, loss: 3.658533
# epoch: 14, step:32, tot_step:984, loss: 3.796836
# epoch: 14, step:33, tot_step:985, loss: 3.774370
# epoch: 14, step:34, tot_step:986, loss: 3.658319
# ...
# epoch: 45, step:22, tot_step:3082, loss: 3.107253
# epoch: 45, step:23, tot_step:3083, loss: 3.167946
# epoch: 45, step:24, tot_step:3084, loss: 3.199131
# epoch: 45, step:25, tot_step:3085, loss: 2.696883
# epoch: 45, step:26, tot_step:3086, loss: 2.735002
# epoch: 45, step:27, tot_step:3087, loss: 3.212506
# epoch: 45, step:28, tot_step:3088, loss: 3.135960
# epoch: 45, step:29, tot_step:3089, loss: 3.272344
# epoch: 45, step:30, tot_step:3090, loss: 2.875927
# epoch: 45, step:31, tot_step:3091, loss: 3.270393
# epoch: 45, step:32, tot_step:3092, loss: 3.077660
# epoch: 45, step:33, tot_step:3093, loss: 3.364628
# epoch: 45, step:34, tot_step:3094, loss: 3.111282
# epoch: 45, step:35, tot_step:3095, loss: 3.303351
# epoch: 45, step:36, tot_step:3096, loss: 3.597373
# epoch: 45, step:37, tot_step:3097, loss: 3.125583
# epoch: 45, step:38, tot_step:3098, loss: 3.250562
# epoch: 45, step:39, tot_step:3099, loss: 3.181447
# epoch: 45, step:40, tot_step:3100, loss: 3.280483
# epoch: 45, step:41, tot_step:3101, loss: 2.918861
# epoch: 45, step:42, tot_step:3102, loss: 3.025532
# epoch: 45, step:43, tot_step:3103, loss: 3.352270
# epoch: 45, step:44, tot_step:3104, loss: 3.445947
# epoch: 45, step:45, tot_step:3105, loss: 3.097608
# epoch: 45, step:46, tot_step:3106, loss: 3.595748
# epoch: 45, step:47, tot_step:3107, loss: 3.751307
# epoch: 45, step:48, tot_step:3108, loss: 3.980284
# epoch: 45, step:49, tot_step:3109, loss: 3.469399
# epoch: 45, step:50, tot_step:3110, loss: 3.239769
# epoch: 45, step:51, tot_step:3111, loss: 3.160016
# epoch: 45, step:52, tot_step:3112, loss: 3.289523
# epoch: 45, step:53, tot_step:3113, loss: 3.293231
# epoch: 45, step:54, tot_step:3114, loss: 3.317623
# epoch: 45, step:55, tot_step:3115, loss: 3.187826
# epoch: 45, step:56, tot_step:3116, loss: 3.567184
# epoch: 45, step:57, tot_step:3117, loss: 3.618490
# epoch: 45, step:58, tot_step:3118, loss: 3.040442
# epoch: 45, step:59, tot_step:3119, loss: 3.033082
# epoch: 45, step:60, tot_step:3120, loss: 3.423149
# epoch: 45, step:61, tot_step:3121, loss: 3.370833
# epoch: 45, step:62, tot_step:3122, loss: 3.237508
# epoch: 45, step:63, tot_step:3123, loss: 2.943604
# epoch: 45, step:64, tot_step:3124, loss: 2.880811
# epoch: 45, step:65, tot_step:3125, loss: 3.228212
# epoch: 45, step:66, tot_step:3126, loss: 2.541245
# epoch: 45, step:67, tot_step:3127, loss: 2.875601
# epoch: 46, step:0, tot_step:3128, loss: 3.647156
# valid loss: 3.307340621948242
# epoch: 46, step:1, tot_step:3129, loss: 3.417500
# epoch: 46, step:2, tot_step:3130, loss: 3.129126
# epoch: 46, step:3, tot_step:3131, loss: 3.051550
# epoch: 46, step:4, tot_step:3132, loss: 3.110749
# epoch: 46, step:5, tot_step:3133, loss: 3.194836
# epoch: 46, step:6, tot_step:3134, loss: 3.348717
# epoch: 46, step:7, tot_step:3135, loss: 3.480655
# epoch: 46, step:8, tot_step:3136, loss: 3.375884
# epoch: 46, step:9, tot_step:3137, loss: 3.301526
# epoch: 46, step:10, tot_step:3138, loss: 3.119591
# epoch: 46, step:11, tot_step:3139, loss: 3.275511
# epoch: 46, step:12, tot_step:3140, loss: 3.366328
# epoch: 46, step:13, tot_step:3141, loss: 3.620457
# epoch: 46, step:14, tot_step:3142, loss: 3.220173
# epoch: 46, step:15, tot_step:3143, loss: 3.298459
# epoch: 46, step:16, tot_step:3144, loss: 3.120101
# epoch: 46, step:17, tot_step:3145, loss: 3.120918
# epoch: 46, step:18, tot_step:3146, loss: 3.878889
# epoch: 46, step:19, tot_step:3147, loss: 3.060858
# epoch: 46, step:20, tot_step:3148, loss: 3.078417
# epoch: 46, step:21, tot_step:3149, loss: 2.899766
# epoch: 46, step:22, tot_step:3150, loss: 3.029954
# epoch: 46, step:23, tot_step:3151, loss: 3.175167
# epoch: 46, step:24, tot_step:3152, loss: 2.940015
# epoch: 46, step:25, tot_step:3153, loss: 3.047163
# epoch: 46, step:26, tot_step:3154, loss: 3.005991
# epoch: 46, step:27, tot_step:3155, loss: 3.302648
# epoch: 46, step:28, tot_step:3156, loss: 3.086549
# epoch: 46, step:29, tot_step:3157, loss: 2.982014
# epoch: 46, step:30, tot_step:3158, loss: 3.095407
# epoch: 46, step:31, tot_step:3159, loss: 2.925040
# epoch: 46, step:32, tot_step:3160, loss: 2.744464
# epoch: 46, step:33, tot_step:3161, loss: 3.281369
# epoch: 46, step:34, tot_step:3162, loss: 3.334113
# epoch: 46, step:35, tot_step:3163, loss: 3.532509
# epoch: 46, step:36, tot_step:3164, loss: 3.319136
# epoch: 46, step:37, tot_step:3165, loss: 2.800169
# epoch: 46, step:38, tot_step:3166, loss: 3.223637
# epoch: 46, step:39, tot_step:3167, loss: 3.392590
# epoch: 46, step:40, tot_step:3168, loss: 3.058862
# epoch: 46, step:41, tot_step:3169, loss: 3.496240
# epoch: 46, step:42, tot_step:3170, loss: 2.775755
# epoch: 46, step:43, tot_step:3171, loss: 2.893578
# epoch: 46, step:44, tot_step:3172, loss: 3.096749
# epoch: 46, step:45, tot_step:3173, loss: 3.218415
# epoch: 46, step:46, tot_step:3174, loss: 2.840501
# epoch: 46, step:47, tot_step:3175, loss: 3.069869
# epoch: 46, step:48, tot_step:3176, loss: 3.276336
# epoch: 46, step:49, tot_step:3177, loss: 3.545844
# epoch: 46, step:50, tot_step:3178, loss: 3.226413
# epoch: 46, step:51, tot_step:3179, loss: 3.352262
# epoch: 46, step:52, tot_step:3180, loss: 3.112654
# epoch: 46, step:53, tot_step:3181, loss: 3.486153
# epoch: 46, step:54, tot_step:3182, loss: 2.915654
# epoch: 46, step:55, tot_step:3183, loss: 3.030575
# epoch: 46, step:56, tot_step:3184, loss: 3.292490
# epoch: 46, step:57, tot_step:3185, loss: 3.410763
# epoch: 46, step:58, tot_step:3186, loss: 2.869980
# epoch: 46, step:59, tot_step:3187, loss: 3.218183
# epoch: 46, step:60, tot_step:3188, loss: 3.228906
# epoch: 46, step:61, tot_step:3189, loss: 3.109129
# epoch: 46, step:62, tot_step:3190, loss: 3.281623
# epoch: 46, step:63, tot_step:3191, loss: 3.208892
# epoch: 46, step:64, tot_step:3192, loss: 3.253132
# epoch: 46, step:65, tot_step:3193, loss: 2.494262
# epoch: 46, step:66, tot_step:3194, loss: 3.183334
# epoch: 46, step:67, tot_step:3195, loss: 2.596375
# epoch: 47, step:0, tot_step:3196, loss: 2.733072
# valid loss: 3.221698045730591
# epoch: 47, step:1, tot_step:3197, loss: 3.428574
# epoch: 47, step:2, tot_step:3198, loss: 3.159815
# epoch: 47, step:3, tot_step:3199, loss: 3.059490
# epoch: 47, step:4, tot_step:3200, loss: 3.337729
# epoch: 47, step:5, tot_step:3201, loss: 2.847715
# epoch: 47, step:6, tot_step:3202, loss: 3.345556
# epoch: 47, step:7, tot_step:3203, loss: 2.795555
# epoch: 47, step:8, tot_step:3204, loss: 3.254803
# epoch: 47, step:9, tot_step:3205, loss: 3.421125
# epoch: 47, step:10, tot_step:3206, loss: 2.892969
# epoch: 47, step:11, tot_step:3207, loss: 3.581679
# epoch: 47, step:12, tot_step:3208, loss: 3.453496
# epoch: 47, step:13, tot_step:3209, loss: 2.847226
# epoch: 47, step:14, tot_step:3210, loss: 3.342616
# epoch: 47, step:15, tot_step:3211, loss: 3.254731
# epoch: 47, step:16, tot_step:3212, loss: 3.374183
# epoch: 47, step:17, tot_step:3213, loss: 2.942487
# epoch: 47, step:18, tot_step:3214, loss: 3.007255
# epoch: 47, step:19, tot_step:3215, loss: 3.186969
# epoch: 47, step:20, tot_step:3216, loss: 2.988412
# epoch: 47, step:21, tot_step:3217, loss: 2.979829
# epoch: 47, step:22, tot_step:3218, loss: 3.460547
# epoch: 47, step:23, tot_step:3219, loss: 3.330628
# epoch: 47, step:24, tot_step:3220, loss: 3.184072
# epoch: 47, step:25, tot_step:3221, loss: 3.461633
# epoch: 47, step:26, tot_step:3222, loss: 3.219032
# epoch: 47, step:27, tot_step:3223, loss: 3.359333
# epoch: 47, step:28, tot_step:3224, loss: 3.578882
# epoch: 47, step:29, tot_step:3225, loss: 3.272021
# epoch: 47, step:30, tot_step:3226, loss: 3.330339
# epoch: 47, step:31, tot_step:3227, loss: 3.342120
# epoch: 47, step:32, tot_step:3228, loss: 2.819317
# epoch: 47, step:33, tot_step:3229, loss: 2.985803
# epoch: 47, step:34, tot_step:3230, loss: 3.103215
# epoch: 47, step:35, tot_step:3231, loss: 3.105224
# epoch: 47, step:36, tot_step:3232, loss: 3.158552
# epoch: 47, step:37, tot_step:3233, loss: 3.220201
# epoch: 47, step:38, tot_step:3234, loss: 3.109794
# epoch: 47, step:39, tot_step:3235, loss: 3.434198
# epoch: 47, step:40, tot_step:3236, loss: 3.251981
# epoch: 47, step:41, tot_step:3237, loss: 3.174199
# epoch: 47, step:42, tot_step:3238, loss: 3.381948
# epoch: 47, step:43, tot_step:3239, loss: 2.674914
# epoch: 47, step:44, tot_step:3240, loss: 2.679505
# epoch: 47, step:45, tot_step:3241, loss: 3.498442
# epoch: 47, step:46, tot_step:3242, loss: 3.352742
# epoch: 47, step:47, tot_step:3243, loss: 3.265842
# epoch: 47, step:48, tot_step:3244, loss: 3.466663
# epoch: 47, step:49, tot_step:3245, loss: 2.936403
# epoch: 47, step:50, tot_step:3246, loss: 3.170801
# epoch: 47, step:51, tot_step:3247, loss: 3.086919
# epoch: 47, step:52, tot_step:3248, loss: 2.970877
# epoch: 47, step:53, tot_step:3249, loss: 2.979892
# epoch: 47, step:54, tot_step:3250, loss: 2.752123
# epoch: 47, step:55, tot_step:3251, loss: 2.926765
# epoch: 47, step:56, tot_step:3252, loss: 3.150015
# epoch: 47, step:57, tot_step:3253, loss: 2.890598
# epoch: 47, step:58, tot_step:3254, loss: 3.021997
# epoch: 47, step:59, tot_step:3255, loss: 3.143252
# epoch: 47, step:60, tot_step:3256, loss: 3.296824
# epoch: 47, step:61, tot_step:3257, loss: 2.939625
# epoch: 47, step:62, tot_step:3258, loss: 2.987506
# epoch: 47, step:63, tot_step:3259, loss: 3.049872
# epoch: 47, step:64, tot_step:3260, loss: 3.044887
# epoch: 47, step:65, tot_step:3261, loss: 3.454908
# epoch: 47, step:66, tot_step:3262, loss: 3.442794
# epoch: 47, step:67, tot_step:3263, loss: 2.660228
# epoch: 48, step:0, tot_step:3264, loss: 3.047960
# valid loss: 3.2041072845458984
# epoch: 48, step:1, tot_step:3265, loss: 3.497607
# epoch: 48, step:2, tot_step:3266, loss: 3.446921
# epoch: 48, step:3, tot_step:3267, loss: 3.166846
# epoch: 48, step:4, tot_step:3268, loss: 3.406315
# epoch: 48, step:5, tot_step:3269, loss: 3.018733
# epoch: 48, step:6, tot_step:3270, loss: 3.372671
# epoch: 48, step:7, tot_step:3271, loss: 3.056844
# epoch: 48, step:8, tot_step:3272, loss: 2.677831
# epoch: 48, step:9, tot_step:3273, loss: 3.198222
# epoch: 48, step:10, tot_step:3274, loss: 3.219538
# epoch: 48, step:11, tot_step:3275, loss: 2.973215
# epoch: 48, step:12, tot_step:3276, loss: 3.508272
# epoch: 48, step:13, tot_step:3277, loss: 2.802510
# epoch: 48, step:14, tot_step:3278, loss: 2.787552
# epoch: 48, step:15, tot_step:3279, loss: 2.948472
# epoch: 48, step:16, tot_step:3280, loss: 3.519741
# epoch: 48, step:17, tot_step:3281, loss: 3.340738
# epoch: 48, step:18, tot_step:3282, loss: 3.325323
# epoch: 48, step:19, tot_step:3283, loss: 3.339971
# epoch: 48, step:20, tot_step:3284, loss: 2.820742
# epoch: 48, step:21, tot_step:3285, loss: 2.822200
# epoch: 48, step:22, tot_step:3286, loss: 3.252597
# epoch: 48, step:23, tot_step:3287, loss: 3.422884
# epoch: 48, step:24, tot_step:3288, loss: 3.288602
# epoch: 48, step:25, tot_step:3289, loss: 2.787957
# epoch: 48, step:26, tot_step:3290, loss: 3.345806
# epoch: 48, step:27, tot_step:3291, loss: 2.960210
# epoch: 48, step:28, tot_step:3292, loss: 3.204961
# epoch: 48, step:29, tot_step:3293, loss: 2.825043
# epoch: 48, step:30, tot_step:3294, loss: 3.320970
# epoch: 48, step:31, tot_step:3295, loss: 3.188517
# epoch: 48, step:32, tot_step:3296, loss: 2.883838
# epoch: 48, step:33, tot_step:3297, loss: 3.269408
# epoch: 48, step:34, tot_step:3298, loss: 3.006565
# epoch: 48, step:35, tot_step:3299, loss: 3.416183
# epoch: 48, step:36, tot_step:3300, loss: 2.722718
# epoch: 48, step:37, tot_step:3301, loss: 3.002690
# epoch: 48, step:38, tot_step:3302, loss: 2.840087
# epoch: 48, step:39, tot_step:3303, loss: 3.128364
# epoch: 48, step:40, tot_step:3304, loss: 2.707818
# epoch: 48, step:41, tot_step:3305, loss: 3.204534
# epoch: 48, step:42, tot_step:3306, loss: 3.010478
# epoch: 48, step:43, tot_step:3307, loss: 3.184380
# epoch: 48, step:44, tot_step:3308, loss: 3.633072
# epoch: 48, step:45, tot_step:3309, loss: 3.347188
# epoch: 48, step:46, tot_step:3310, loss: 3.563179
# epoch: 48, step:47, tot_step:3311, loss: 2.907322
# epoch: 48, step:48, tot_step:3312, loss: 3.010654
# epoch: 48, step:49, tot_step:3313, loss: 2.959884
# epoch: 48, step:50, tot_step:3314, loss: 3.166775
# epoch: 48, step:51, tot_step:3315, loss: 3.463209
# epoch: 48, step:52, tot_step:3316, loss: 3.065187
# epoch: 48, step:53, tot_step:3317, loss: 3.259535
# epoch: 48, step:54, tot_step:3318, loss: 2.781865
# epoch: 48, step:55, tot_step:3319, loss: 3.142462
# epoch: 48, step:56, tot_step:3320, loss: 3.331523
# epoch: 48, step:57, tot_step:3321, loss: 3.446761
# epoch: 48, step:58, tot_step:3322, loss: 3.145483
# epoch: 48, step:59, tot_step:3323, loss: 3.131429
# epoch: 48, step:60, tot_step:3324, loss: 3.281345
# epoch: 48, step:61, tot_step:3325, loss: 2.774341
# epoch: 48, step:62, tot_step:3326, loss: 3.007306
# epoch: 48, step:63, tot_step:3327, loss: 3.400991
# epoch: 48, step:64, tot_step:3328, loss: 3.031958
# epoch: 48, step:65, tot_step:3329, loss: 3.441689
# epoch: 48, step:66, tot_step:3330, loss: 2.968744
# epoch: 48, step:67, tot_step:3331, loss: 3.507654
# epoch: 49, step:0, tot_step:3332, loss: 3.076591
# valid loss: 3.203378200531006
# epoch: 49, step:1, tot_step:3333, loss: 3.189632
# epoch: 49, step:2, tot_step:3334, loss: 3.082015
# epoch: 49, step:3, tot_step:3335, loss: 2.937632
# epoch: 49, step:4, tot_step:3336, loss: 3.636098
# epoch: 49, step:5, tot_step:3337, loss: 3.472732
# epoch: 49, step:6, tot_step:3338, loss: 3.036530
# epoch: 49, step:7, tot_step:3339, loss: 2.974699
# epoch: 49, step:8, tot_step:3340, loss: 2.771405
# epoch: 49, step:9, tot_step:3341, loss: 3.597709
# epoch: 49, step:10, tot_step:3342, loss: 3.058768
# epoch: 49, step:11, tot_step:3343, loss: 3.121702
# epoch: 49, step:12, tot_step:3344, loss: 3.068254
# epoch: 49, step:13, tot_step:3345, loss: 3.149594
# epoch: 49, step:14, tot_step:3346, loss: 3.174576
# epoch: 49, step:15, tot_step:3347, loss: 3.445842
# epoch: 49, step:16, tot_step:3348, loss: 2.609030
# epoch: 49, step:17, tot_step:3349, loss: 3.081145
# epoch: 49, step:18, tot_step:3350, loss: 2.902946
# epoch: 49, step:19, tot_step:3351, loss: 2.948869
# epoch: 49, step:20, tot_step:3352, loss: 3.019101
# epoch: 49, step:21, tot_step:3353, loss: 3.049834
# epoch: 49, step:22, tot_step:3354, loss: 3.430357
# epoch: 49, step:23, tot_step:3355, loss: 3.048882
# epoch: 49, step:24, tot_step:3356, loss: 2.847500
# epoch: 49, step:25, tot_step:3357, loss: 3.013836
# epoch: 49, step:26, tot_step:3358, loss: 2.998846
# epoch: 49, step:27, tot_step:3359, loss: 3.455025
# epoch: 49, step:28, tot_step:3360, loss: 3.195835
# epoch: 49, step:29, tot_step:3361, loss: 3.325464
# epoch: 49, step:30, tot_step:3362, loss: 3.105801
# epoch: 49, step:31, tot_step:3363, loss: 3.200164
# epoch: 49, step:32, tot_step:3364, loss: 3.072731
# epoch: 49, step:33, tot_step:3365, loss: 2.874711
# epoch: 49, step:34, tot_step:3366, loss: 3.072022
# epoch: 49, step:35, tot_step:3367, loss: 3.472542
# epoch: 49, step:36, tot_step:3368, loss: 3.210841
# epoch: 49, step:37, tot_step:3369, loss: 3.117880
# epoch: 49, step:38, tot_step:3370, loss: 3.017578
# epoch: 49, step:39, tot_step:3371, loss: 3.220816
# epoch: 49, step:40, tot_step:3372, loss: 3.679132
# epoch: 49, step:41, tot_step:3373, loss: 3.235507
# epoch: 49, step:42, tot_step:3374, loss: 3.164204
# epoch: 49, step:43, tot_step:3375, loss: 2.716835
# epoch: 49, step:44, tot_step:3376, loss: 3.038542
# epoch: 49, step:45, tot_step:3377, loss: 3.090402
# epoch: 49, step:46, tot_step:3378, loss: 3.325828
# epoch: 49, step:47, tot_step:3379, loss: 3.400753
# epoch: 49, step:48, tot_step:3380, loss: 3.126084
# epoch: 49, step:49, tot_step:3381, loss: 3.089185
# epoch: 49, step:50, tot_step:3382, loss: 2.659289
# epoch: 49, step:51, tot_step:3383, loss: 3.243342
# epoch: 49, step:52, tot_step:3384, loss: 3.044263
# epoch: 49, step:53, tot_step:3385, loss: 3.084320
# epoch: 49, step:54, tot_step:3386, loss: 3.162038
# epoch: 49, step:55, tot_step:3387, loss: 3.405846
# epoch: 49, step:56, tot_step:3388, loss: 3.394835
# epoch: 49, step:57, tot_step:3389, loss: 3.338739
# epoch: 49, step:58, tot_step:3390, loss: 3.344871
# epoch: 49, step:59, tot_step:3391, loss: 2.925604
# epoch: 49, step:60, tot_step:3392, loss: 3.109395
# epoch: 49, step:61, tot_step:3393, loss: 2.988961
# epoch: 49, step:62, tot_step:3394, loss: 2.912893
# epoch: 49, step:63, tot_step:3395, loss: 3.142998
# epoch: 49, step:64, tot_step:3396, loss: 2.792201
# epoch: 49, step:65, tot_step:3397, loss: 2.986287
# epoch: 49, step:66, tot_step:3398, loss: 3.392440
# epoch: 49, step:67, tot_step:3399, loss: 2.674906

# %% [markdown]
# ## 오디오 파일 생성

# %% [markdown]
# * 학습이 끝난 Trainer 객체를 사용해 wav 파일 생성
# * 생성된 wav 파일 확인

# %%
tr.generate()

# %%
import glob
import IPython.display as ipd

path = glob.glob('./samples/*.wav')[3]
ipd.Audio(path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
