# %% [markdown]
# # BeautyfulSoup 네이버 뉴스 기사 스크래핑

# %% [markdown]
# ## 뉴스 기사 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd

def get_news(query, page_num = 10):

    news_df = pd.DataFrame(columns = ('title','link','press','datetime','article'))
    idx = 0

    url_query = quote(query)    # quote를 통해 인코딩 바꾼걸
    url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query=' + url_query  #url에 넣어주는거지

    for _ in range(0,page_num):
        
        search_url = urllib.request.urlopen(url).read()
        soup = BeautifulSoup(search_url, 'html.parser')
        links = soup.find_all('dd',{'class':'txt_inline'})

        
        for link in links:
            press = link.find('span',{'class' : '_sp_each_source'}).get_text()
            news_url  = link.find('a').get('href')

            if (news_url == '#'):
                continue
            else:
                news_link = urllib.request.urlopen(news_url).read()
                news_html =  BeautifulSoup(news_link, 'html.parser')

            try:
                title = news_html.find('h3', {'id':'articleTitle'}).get_text()
                datetime = news_html.find('span', {'class': 't11'}).get_text()
                article = news_html.find('div', {'id':'articleBodyContents'}).get_text()
                article = article.replace('// flash 오류를 우회하기 위한 함수 추가', '')
                article = article.replace('function _flash_removeCallback() {}', '')
                article = article.replace('\n', '')
                article = article.replace('\t', '')

                news_df.loc[idx] = [title,news_url,press,datetime,article]
                idx += 1
                print('#',end = '')
            except:
                continue

        try:
            next = soup.find('a', {'class':'next'}).get('href')
            url = 'http://search.naver.com/search.naver' +next
        except:
            break

    return news_df

# %%
query = input('검색:')

news_df = get_news(query , 10)
print('done')
# Out:
# 검색:게임
# ################################################done

# %%
news_df
# Out:
#                                                 title  ...                                            article
# 0                       1.8억원어치 대리게임 해준 유명 대리업체 5곳 검거  ...  게임위·전남警 합동수사···운영자 6명 입건작년 대리게임처벌법 시행 후 첫 검거 사...
# 1                          청주시, 카드게임 대회 2주간 집합금지 행정명령  ...  '홀덤 게임 대회' 집합금지 행정명령[청주시 제공. 재판매 및 DB 금지](청주=연...
# 2                         정부-의사 ‘치킨게임’...파업 장기화 수순 밟나  ...  대한의사협회가 사흘간의 2차 의사총파업에 돌입한 26일 서울 송파구의 한 대형병원에...
# 3                          넷마블 마구마구2020, 새 게임 모드 업데이트  ...  (지디넷코리아=이도원  기자)넷마블(대표 권영식, 이승원)은 야구게임 &apos마구...
# 4                        [따져보니] 의사파업 '치킨 게임' 치닫는 이유는?  ...  [앵커]정부와 의료계 대립이 극단으로 치닫고 있는데 왜 이러한 상황까지 오게 됐는지...
# 5                                    [이도경의 플레e] 법과 게임  ...  [파이낸셜뉴스] 게임산업진흥법, e스포츠진흥법, 정보통신이용망법, 청소년보호법 등 ...
# 6          [전화성의 기술창업 Targeting]133.게임 스타트업의 콘텐츠 기술혁신  ...  3조달러를 바라보는 세계 콘텐츠 시장에서 우리나라는 700만달러 규모의 세계 7위권...
# 7                            게임업계도 힘들다 “상반기 실적 달성 못해”  ...  이성환 KT 5G·기가사업본부장이 지난 12일 서울 세종대로 광화문KT에서 콘솔·P...
# 8                        [따져보니] 의사파업 '치킨 게임' 치닫는 이유는?  ...  [앵커]정부와 의료계 대립이 극단으로 치닫고 있는데 왜 이러한 상황까지 오게 됐는지...
# 43                  2분기 동남아 모바일 게임 시장 급성장...전년대비 44%↑  ...  중국 게임이 주도...상위 10개중 8개가 중국산(지디넷코리아=유효정  중국 전문기...
# 44                             PC 게임 사망여각, 킥스타터 모금 시작  ...  9월 29일까지 총 35일간 모금 펀딩...목표 금액 약 1천780만 원(지디넷코리...
# 45              '지루한' 파월의 '극적인' 게임체인지...'볼커-그린스펀'과 결별  ...  평균물가안정목표제는 물가보다는 '고용 안정'을 더 중시하는 정책파월 "완전고용에서 ...
# 46                    조이시티, 내년까지 출시할 신작 모바일게임 5종 곧 공개  ...  조이시티가 오는 9월 3일 온라인 신작 발표회를 통해 자사의 신작 모바일게임 5종을...
# 47                      '슈퍼전파자' 전광훈의 '진실게임'…처벌은 솜방망이?  ...  사랑제일교회발 집단감염 장본인 정광훈 동선 '비상'사택 머물렀다 진술했지만, 유튜브...
#
# [48 rows x 5 columns]

# %%
news_df['article']
# Out:
# 0     게임위·전남警 합동수사···운영자 6명 입건작년 대리게임처벌법 시행 후 첫 검거 사...
# 1     '홀덤 게임 대회' 집합금지 행정명령[청주시 제공. 재판매 및 DB 금지](청주=연...
# 2     대한의사협회가 사흘간의 2차 의사총파업에 돌입한 26일 서울 송파구의 한 대형병원에...
# 3     (지디넷코리아=이도원  기자)넷마블(대표 권영식, 이승원)은 야구게임 &apos마구...
# 4     [앵커]정부와 의료계 대립이 극단으로 치닫고 있는데 왜 이러한 상황까지 오게 됐는지...
# 5     [파이낸셜뉴스] 게임산업진흥법, e스포츠진흥법, 정보통신이용망법, 청소년보호법 등 ...
# 6     3조달러를 바라보는 세계 콘텐츠 시장에서 우리나라는 700만달러 규모의 세계 7위권...
# 7     이성환 KT 5G·기가사업본부장이 지난 12일 서울 세종대로 광화문KT에서 콘솔·P...
# 8     [앵커]정부와 의료계 대립이 극단으로 치닫고 있는데 왜 이러한 상황까지 오게 됐는지...
# 9     리그 오브 레전드와 (여자)아이들 미연과 소연 등 협업  [파이낸셜뉴스] 글로벌 온...
# 10    던전앤파이터·크로스파이어·리니지할리우드도 '군침'게임 IP의 무한확장 크로스파이어 ...
# 11    삼성, 내달 1일 공개  외부·내부 디스플레이 개선  4.6 → 6.2  7.3 →...
# 12    엔씨소프트 순환재택근무 2주 더 연장(지디넷코리아=이도원  기자)주요 게임사들이 순...
# 13    3조달러를 바라보는 세계 콘텐츠 시장에서 우리나라는 700만달러 규모의 세계 7위권...
# 14    연내 대만 출시 계획(지디넷코리아=이도원  기자)엠게임(대표 권이형)은 해피툭과 모...
# 15    내년에 북미‧유럽 출시하는 엔드오브드래곤즈 예고  [파이낸셜뉴스] 엔씨소프트 북미법...
# 16    240개 채널 시청+인기 월정액 매월 변경 가능‘VIP 전용관·지포스나우 프리미엄·...
# 17    신간 '나는 게이머입니다. 아, 여자고요'…게임계 여성 혐오 뿌리 들춰여성 게이머 ...
# 18    의료계 집단휴진 이틀째… 강대강 대치 계속중수본 “휴진자 358명 대상 명령서 발부...
# 19    지난해 9월6일 조국 전 법무부 장관의 국회 인사청문회 당일 기소된 정경심 동양대 ...
# 20    신규 이벤트 '핑키의 과일농장' 1300만건 플레이[아이뉴스24 문영수 기자] 모바...
# 21    게임빌(대표 송병준)은 모바일 낚시게임 ‘피싱마스터’에서 ‘알로하 페스티벌’ 이벤트...
# 22    스마일게이트, 중국서 게임 드라마화 성공… IP가 게임⋅엔터 결합 매개크래프톤, 드...
# 23    지난해 영화 '존 윅'에 이은 두번째 협업'빛의 제공자' 자' 업데이트 안내 페이지...
# 24    [이데일리 김재은 기자] 한화투자증권은 28일 미스터블루(207760)에 대해 만화...
# 25    오는 9월 출시 예정..손흥민 캠페인 모델로 선정안전성·넓은 공간 내세워 쟁쟁한 강...
# 26    ▲ 심즈 4 '스타워즈: 바투 행성의 모험' 게임팩 (사진출처: 심즈 4 공식 사이...
# 27    북한 애니메이션 다람이와 고슴도치 32화의 한 장면.북한 게임이 변하고 있다. 체제...
# 28    ▲ 자칭 '노인 아수라장 샌드박스 게임' 저스트 다이 올레디 (사진: 공식 영상 갈...
# 29    와이제이엠게임즈(대표이사 민용재)가 서브컬처 전략게임 '라스트 커맨더'를 국내에 정...
# 30    이하 데일리메일열두 개의 손가락을 가진 덕에 게임에서 이길 수 있다며 다지증을 자랑...
# 31    ‘엘리온’ 등 신작 MMORPG 제작팀으로 구성  [파이낸셜뉴스] ‘배틀그라운드’ ...
# 32    플레로게임즈는 라이크잇게임즈가 개발한 모바일 캐주얼 게임 '당신에게 고양이가'(De...
# 33    PC·콘솔 등도 플랫폼 확장넷마블이 그동안 약점으로 지적 받아온 자체 지식재산권(I...
# 34    "2021년까지 10개 이상 신작 라인업 발표…개발사 추가 인수·합병 계획"남궁훈 ...
# 35    2분기 매출액 전년 동기 대비 2.7% 감소당초 전문가 기대치보다 약 2500억원 ...
# 36    카카오 등에 업고 신사업 확장카카오 플랫폼을 등에 업은 카카오게임즈가 국내 게임 산...
# 37    데브시스터즈는 서비스 중인 모바일 게임 '쿠키런: 오븐브레이크'에서 공포 콘셉트의 ...
# 38    컴투스·네오위즈·드래곤플라이 참가…온라인 전시회 살펴보니[아이뉴스24 문영수 기자]...
# 39    창유(지사장 최혜연)는 미소녀 모바일게임 ‘일루전 커넥트’를 오는 9월 10일 국내...
# 40    (지디넷코리아=김한준  기자)이기몹은 28일 독일의 미디어 그룹 코흐 미디어와 자사...
# 41    28일 신한금융투자는 조이시티의 주요 전쟁게임의 매출 상승이 지속되고 있다며 성장성...
# 42    NH농협은행은 e스포츠의 성장을 지원하고 젊은층 고객과의 소통 강화를 위해 아프리카...
# 43    중국 게임이 주도...상위 10개중 8개가 중국산(지디넷코리아=유효정  중국 전문기...
# 44    9월 29일까지 총 35일간 모금 펀딩...목표 금액 약 1천780만 원(지디넷코리...
# 45    평균물가안정목표제는 물가보다는 '고용 안정'을 더 중시하는 정책파월 "완전고용에서 ...
# 46    조이시티가 오는 9월 3일 온라인 신작 발표회를 통해 자사의 신작 모바일게임 5종을...
# 47    사랑제일교회발 집단감염 장본인 정광훈 동선 '비상'사택 머물렀다 진술했지만, 유튜브...
# Name: article, dtype: object

# %% [markdown]
# ## 뉴스 기사 스크래핑 실행
